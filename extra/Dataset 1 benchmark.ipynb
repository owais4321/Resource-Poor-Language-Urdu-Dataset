# %%
import pandas as pd

# %%
dataset = pd.read_csv("Dataset 1.csv")
stopwords = pd.read_csv('Stopword.csv')

# %%
dataset.tail()
# Out:
#         id                                              tweet  target
# 2395  2764   ہاہاہا میرا سالہ اپنی باجی کی پدی صاف کر رہا ...       1
# 2396  1332   مادر چود کشمیر بیچنے والوں کے بھڑوے بھروے عوا...       1
# 2397  2154   ایک لفظ نہیں بہت سارے ہیں مثلاً کُتا، بے غیرت...       1
# 2398   464  یہ دلّا آدمی رقص کر کر کے آگے کھڑی حجیانیوں کو...       1
# 2399  1300  انڈیا کشمیر میں بچوں تک کو مار رہا ہے اور کُچھ...       0

# %%
stw=[]
for i in stopwords['Stopwords']:
    stw.append(i)

# %%
corpus=[]
for i in (dataset['tweet']):
        #i=remove_punctuation(i)
        review=i.split()
        review=[word for word in review if word not in stw]
        review=' '.join(review)
        corpus.append(review)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer   
vectorizer=TfidfVectorizer()
X = vectorizer.fit_transform(corpus).toarray()

# %%
vectorizer.vocabulary_
# Out:
# {'قوم': 2895,
#  'پرانے': 4040,
#  'خاندانی': 1601,
#  'نمک': 3661,
#  'حرام': 1504,
#  'خنزیروں': 1649,
#  'بغض': 751,
#  'نواز': 3677,
#  'سپورٹ': 2331,
#  'سے': 2418,
#  'پاکستان': 4011,
#  'قبضے': 2860,
#  'اسرائیلی': 236,
#  'پائلٹ': 3976,
#  'ہے': 5337,
#  'شریف': 2467,
#  'نواسہ': 3680,
#  'مستقبل': 3300,
#  'وزیر': 3828,
#  'اعظم': 279,
#  'ٹویٹر': 3929,
#  'پہ': 4204,
#  'بکواس': 912,
#  'آسان': 70,
#  'کشمیوں': 4720,
#  'مشکل': 3317,
#  'وقت': 3849,
#  'تنہا': 1200,
#  'چھوڑے': 4436,
#  'گا': 4979,
#  'جبکہ': 1338,
#  'سندھیوں': 2273,
#  'بلوچوں': 775,
#  'پشتونوں': 4079,
#  'زندہ': 2103,
#  'مادرچود': 3120,
#  'یوتھئے': 5366,
#  'کشمیر': 4715,
#  'ہاتھہ': 5204,
#  'نکل': 3703,
#  'ثالثی': 1269,
#  'نیازی': 3732,
#  'واہ': 3805,
#  'کررہے': 4659,
#  'بھوسڑی': 955,
#  'گانڈو': 4990,
#  'بیچنے': 1077,
#  'کتو': 4618,
#  'عالمی': 2615,
#  'سازش': 2145,
#  'ہمارےسلیکٹڈ': 5245,
#  'سلیکٹرز': 2241,
#  'کےمنہ': 4966,
#  'سعودی': 2218,
#  'عرب': 2632,
#  'شرمناک': 2457,
#  'طمانچہ': 2593,
#  'کتی': 4623,
#  'بچے': 889,
#  'گھٹیا': 5124,
#  'تم': 1183,
#  'پیداوار': 4236,
#  'بہتر': 1012,
#  'انکو': 429,
#  'گھر': 5108,
#  'بھیج': 993,
#  'کنجروں': 4768,
#  'موجیں': 3461,
#  'نیب': 3733,
#  'ڈرامہ': 4496,
#  'آج': 44,
#  'دل': 1765,
#  'خدا': 1615,
#  'قسم': 2878,
#  'خون': 1676,
#  'آنسو': 100,
#  'رویا': 2009,
#  'قبرستان': 2857,
#  'قبروں': 2858,
#  'حالت': 1485,
#  'دیکھی': 1886,
#  'لعنت': 2954,
#  'ٹوٹ': 3922,
#  'شرمی': 2460,
#  'انتہا': 375,
#  'اندر': 386,
#  'رنڈی': 1974,
#  'وآپس': 3771,
#  'عوام': 2677,
#  'جہاں': 1455,
#  'نظر': 3636,
#  'پکڑ': 4173,
#  'گانڈ': 4989,
#  'کیڑا': 4943,
#  'مارے': 3139,
#  'جاو': 1310,
#  'جاکر': 1316,
#  'کشمیریوں': 4719,
#  'ساتھ': 2131,
#  'مل': 3381,
#  'جنگ': 1400,
#  'کرو': 4679,
#  'جنرل': 1394,
#  'باجوہ': 601,
#  'نام': 3573,
#  'سن': 2262,
#  'مودی': 3462,
#  'ٹانگیں': 3897,
#  'کانپتی': 4599,
#  'آرمی': 60,
#  'چیف': 4457,
#  'لوامہ': 2983,
#  'بھارتی': 924,
#  'فوج': 2809,
#  'ڈنڈا': 4511,
#  'کیسی': 4923,
#  'خبیث': 1613,
#  'انسان': 396,
#  'جسکے': 1364,
#  'مرنے': 3266,
#  'ہمیں': 5254,
#  'خوشی': 1671,
#  'لعنتی': 2955,
#  'پتا': 4021,
#  'کب': 4607,
#  'مرے': 3278,
#  'کتے': 4625,
#  'موت': 3455,
#  'شروع': 2462,
#  'برا': 706,
#  'لگتا': 3070,
#  'زندگی': 2102,
#  'پہلا': 4210,
#  'ووٹ': 3857,
#  'بار': 607,
#  'سلیکشن': 2240,
#  'گورایہ': 5083,
#  'گٹر': 5102,
#  'فوجیستان': 2811,
#  'بس': 739,
#  'کام': 4588,
#  'ھےالطاف': 5192,
#  'بھائی': 920,
#  'کےاوپر': 4950,
#  'پابندی': 3983,
#  'تالا': 1105,
#  'ڈال': 4472,
#  'مریم': 3276,
#  'احتساب': 179,
#  'عدالت': 2628,
#  'بلا': 757,
#  'سیکنڈز': 2409,
#  'دن': 1789,
#  'ریمانڈ': 2060,
#  'دلوانا': 1775,
#  'تیز': 1259,
#  'ترین': 1146,
#  'کاروائی': 4557,
#  'پارلمنٹ': 3987,
#  'بلڈنگ': 776,
#  'بھیک': 1005,
#  'بنا': 785,
#  'بند': 807,
#  'گھسرا': 5113,
#  'گھسرے': 5114,
#  'مزہ': 3290,
#  'آۓ': 136,
#  'بھول': 957,
#  'لوگوں': 3010,
#  'زبان': 2079,
#  'بشری': 745,
#  'پیرنی': 4239,
#  'کہاں': 4895,
#  'بنی': 828,
#  'گالہ': 4984,
#  'کتوں': 4622,
#  'لاکھوں': 2939,
#  'مظلوم': 3335,
#  'ممتاز': 3411,
#  'ماں': 3166,
#  'پھودی': 4190,
#  'حرامی': 1515,
#  'بلوایا': 771,
#  'میکاسنگھ': 3542,
#  'انڈیا': 419,
#  'کرنٹ': 4675,
#  'اکاؤنٹ': 504,
#  'خسارہ': 1631,
#  'کمی': 4755,
#  'کامیابی': 4594,
#  'وزیراعظم': 3829,
#  'خاتمہ': 1584,
#  'انشاءلله': 405,
#  'خود': 1661,
#  'سندھی': 2272,
#  'بولتا': 850,
#  'ھے': 5191,
#  'فخر': 2749,
#  'بلوچ': 772,
#  'ھونے': 5172,
#  'بلوچست': 773,
#  'کاش': 4574,
#  'اج': 167,
#  'موچھیں': 3481,
#  'کاٹ': 4600,
#  'پچھواڑا': 4152,
#  'پھاڑ': 4183,
#  'بھیجیں': 1000,
#  'طوفانی': 2599,
#  'بارش': 608,
#  'تباہی': 1115,
#  'مچا': 3491,
#  'سینکڑوں': 2397,
#  'مکانات': 3501,
#  'نقصان': 3650,
#  'سیلابی': 2392,
#  'ریلے': 2059,
#  'محصور': 3210,
#  'محترم': 3205,
#  'جناب': 1387,
#  'انکل': 428,
#  'باجرہ': 598,
#  'ایکسٹینشن': 579,
#  'ٹیوٹ': 3965,
#  'قیامت': 2901,
#  'آگئی': 128,
#  'تھی': 1245,
#  'آپ': 113,
#  'نظریات': 3637,
#  'پہرہ': 4208,
#  'کمینی': 4760,
#  'منہ': 3451,
#  'رکھ': 2018,
#  'سچ': 2333,
#  'حق': 1535,
#  'بولنے': 855,
#  'لکھنے': 3047,
#  'نڈر': 3695,
#  'بیوروچیف': 1054,
#  'ٹرائیبل': 3905,
#  'ٹائمز': 3894,
#  'ڈسٹرک': 4510,
#  'ویسٹ': 3878,
#  'بلدیہ': 768,
#  'ٹاون': 3899,
#  'کراچی': 4635,
#  'میںشہید': 3547,
#  'اوقات': 455,
#  'مادر': 3118,
#  'چود': 4366,
#  'like': 13,
#  'خنزیر': 1647,
#  'اولاد': 458,
#  'جتنا': 1340,
#  'ملک': 3402,
#  'جان': 1294,
#  'بات': 594,
#  'مزاق': 3285,
#  'ہیں': 5335,
#  'بھگوڑی': 990,
#  'لیگ': 3104,
#  'پورے': 4115,
#  'کشمیروں': 4716,
#  'علاوہ': 2656,
#  'چھوڑ': 4432,
#  'غلط': 2712,
#  'برگہ': 724,
#  'کشتہ': 4713,
#  'روز': 1989,
#  'اول': 456,
#  'طبیعت': 2588,
#  'صاف': 2533,
#  'چاہئیے': 4309,
#  'لعنتییوں': 2958,
#  'سیاست': 2367,
#  'لیکر': 3102,
#  'اسٹیبلشمنٹ': 248,
#  'کیسیس': 4924,
#  'کالے': 4587,
#  'کرتوتوں': 4641,
#  'بچاتے': 875,
#  'بہن': 1015,
#  'قومی': 2897,
#  'اثاثے': 165,
#  'برباد': 713,
#  'رھا': 2028,
#  'موقع': 3466,
#  'چمکانے': 4344,
#  'نسل': 3615,
#  'شرم': 2455,
#  'ابے': 151,
#  'مار': 3122,
#  'چودوں': 4372,
#  'یار': 5346,
#  'افغانیوں': 300,
#  'چدائی': 4324,
#  'سفید': 2225,
#  'پتہ': 4028,
#  'ڈرا': 4494,
#  'غلیظ': 2714,
#  'بیان': 1022,
#  'حکومت': 1570,
#  'پکڑتے': 4175,
#  'پاک': 4009,
#  'لائن': 2914,
#  'آف': 76,
#  'کنٹرول': 4775,
#  'اشتعال': 262,
#  'انگیزی': 437,
#  'توڑ': 1216,
#  'جواب': 1411,
#  'کارروائی': 4553,
#  'افسر': 289,
#  'سمیت': 2258,
#  'فوجی': 2810,
#  'ہلاک': 5237,
#  'ایس': 549,
#  'پی': 4223,
#  'آر': 57,
#  'سوگوار': 2315,
#  'اتنے': 162,
#  'کنجری': 4769,
#  'ہو': 5267,
#  'گشتی': 5046,
#  'دلے': 1783,
#  'جھولی': 1437,
#  'بیٹھ': 1062,
#  'جا': 1273,
#  'زراہ': 2090,
#  'غور': 2718,
#  'تیرا': 1256,
#  'بھونکنا': 964,
#  'ہوگا': 5300,
#  'ہتھے': 5218,
#  'مر': 3241,
#  'جاۓ': 1334,
#  'عبدالقدیر': 2620,
#  'خان': 1598,
#  'کارگل': 4567,
#  'دہلی': 1860,
#  'منٹ': 3444,
#  'بٹن': 866,
#  'کلک': 4736,
#  'تباہ': 1114,
#  'کرسکتے': 4662,
#  'تھے': 1247,
#  'یہ': 5387,
#  'لکھتے': 3045,
#  'ریے': 2069,
#  'حلال': 1543,
#  'زادے': 2075,
#  'شک': 2489,
#  'کارتک': 4552,
#  'اچھی': 498,
#  'خاصی': 1592,
#  'چکی': 4415,
#  'کمنٹس': 4751,
#  'لہذا': 3083,
#  'کہوںگا': 4904,
#  'بریکنگ': 731,
#  'نیوز': 3740,
#  'اچانک': 492,
#  'شاندار': 2441,
#  'زرداری': 2091,
#  'اینڈ': 562,
#  'کمپنی': 4753,
#  'کمر': 4747,
#  'خبر': 1610,
#  'پاگل': 4018,
#  'زرا': 2087,
#  'سنبھال': 2266,
#  'بدکردار': 701,
#  'باپ': 639,
#  'واشل': 3784,
#  'گدھا': 5003,
#  'راگنی': 1943,
#  'خوروں': 1665,
#  'نے': 3750,
#  'گدھی': 5004,
#  'بچو': 882,
#  'لگ': 3053,
#  'باری': 612,
#  'لال': 2925,
#  'مرچیں': 3271,
#  'لڑتی': 3027,
#  'گائے': 4980,
#  'پیشاپ': 4249,
#  'پینے': 4260,
#  'گندی': 5073,
#  'کشمیری': 4718,
#  'اللہ': 331,
#  'لاکھ': 2938,
#  'شکر': 2494,
#  'اداکرتے': 203,
#  'ضمیر': 2574,
#  'فروشوں': 2780,
#  'پاکستانیوں': 4015,
#  'چھوٹی': 4429,
#  'علماء': 2659,
#  'کرام': 4633,
#  'آقا': 86,
#  'علیہ': 2665,
#  'السلام': 322,
#  'وارث': 3780,
#  'حثیت': 1495,
#  'بارے': 613,
#  'ٹیکسی': 3970,
#  'لاوارث': 2931,
#  'دنیا': 1791,
#  'بہترین': 1014,
#  'ہتھیار': 5216,
#  'ایمانداری': 558,
#  'تلوار': 1181,
#  'دیانتداری': 1864,
#  'بچی': 886,
#  'خور': 1664,
#  'جھنڈے': 1436,
#  'ناپاک': 3583,
#  'مت': 3175,
#  'شیر': 2521,
#  'کہتے': 4897,
#  'کتا': 4609,
#  'حضرات': 1531,
#  'مسلم': 3308,
#  'حانے': 1491,
#  'خواب': 1654,
#  'دیکھتے': 1881,
#  'جاگ': 1317,
#  'جائیں': 1280,
#  'پوری': 4114,
#  'پر': 4035,
#  'میٹرو': 3536,
#  'پشاور': 4076,
#  'لیگی': 3105,
#  'میڈیا': 3540,
#  'ٹیم': 3961,
#  'پھڈے': 4194,
#  'جاری': 1290,
#  'گے': 5142,
#  'کنجر': 4765,
#  'بیغیرت': 1040,
#  'بیغیرتوں': 1042,
#  'دردی': 1729,
#  'وٹا': 3859,
#  'پن': 4095,
#  'گاڑی': 4994,
#  'لیٹا': 3098,
#  'سوات': 2289,
#  'دوسرے': 1815,
#  'وزیرستانی': 3831,
#  'بن': 784,
#  'گئے': 4978,
#  'دلال': 1767,
#  'بنےگا': 833,
#  'یارب': 5347,
#  'العزت': 324,
#  'شہ': 2503,
#  'رگ': 2027,
#  'جلدازجلد': 1375,
#  'بھارت': 922,
#  'قابض': 2844,
#  'افواج': 302,
#  'آزادی': 68,
#  'نصیب': 3631,
#  'فرماء': 2767,
#  'آمی': 95,
#  'بوری': 846,
#  'ادارے': 199,
#  'وجہ': 3808,
#  'بھونک': 961,
#  'بےغیرت': 1091,
#  'حاجی': 1475,
#  'جامل': 1293,
#  'حالتی': 1486,
#  'انتقال': 373,
#  'کرگئے': 4698,
#  'نماز': 3657,
#  'جنازہ': 1389,
#  'گیارہ': 5132,
#  'بجے': 673,
#  'نڑیل': 3696,
#  'پیر': 4238,
#  'ادا': 196,
#  'جائےگی': 1281,
#  'ٹھوکو': 3951,
#  'ویسے': 3880,
#  'مرواتے': 3269,
#  'تع': 1161,
#  'مشہور': 3320,
#  'زمانہ': 2096,
#  'بےغیرتوں': 1093,
#  'پہچان': 4221,
#  'دوستو': 1807,
#  'قابل': 2845,
#  'اسکے': 258,
#  'سنو': 2276,
#  'حافظ': 1482,
#  'بلاتحقیق': 759,
#  'خارجہ': 1589,
#  'کہنے': 4901,
#  'دشنام': 1749,
#  'طرازی': 2589,
#  'سر': 2180,
#  'جوابي': 1413,
#  'كارواي': 2907,
#  'نهى': 3669,
#  'انكو': 412,
#  'سبق': 2169,
#  'سكها': 2227,
#  'دينا': 1824,
#  'بہنوں': 1017,
#  'بیٹیوں': 1070,
#  'جیل': 1467,
#  'بھیجتی': 996,
#  'سیدھا': 2380,
#  'گولی': 5095,
#  'مارتے': 3127,
#  'کوس': 4794,
#  'ہورہاہے': 5285,
#  'چور': 4377,
#  'چایئے': 4322,
#  'سزا': 2204,
#  'رات': 1921,
#  'کٹ': 4828,
#  'ہات': 5201,
#  'ہولناک': 5290,
#  'خبریں': 1612,
#  'پڑھ': 4165,
#  'گھنٹوں': 5117,
#  'اداس': 200,
#  'حیا': 1573,
#  'معصوم': 3354,
#  'الگ': 342,
#  'گیراج': 5135,
#  'گرفتار': 5019,
#  'کرتے': 4642,
#  'کھوتی': 4870,
#  'پرانی': 4039,
#  'عادتیں': 2612,
#  'خاموشی': 1597,
#  'اختیار': 191,
#  'کرلیتا': 4670,
#  'مسلمان': 3309,
#  'ضیاء': 2576,
#  'جشن': 1367,
#  'منارہے': 3421,
#  'نظریاتی': 3638,
#  'سرحدوں': 2185,
#  'اشد': 264,
#  'ضرورت': 2570,
#  'بیشک': 1034,
#  'ھم': 5157,
#  'گناہگار': 5064,
#  'سیاہکار': 2374,
#  'دیکھیں': 1887,
#  'حامد': 1489,
#  'ماضی': 3143,
#  'ایکسٹنشنز': 578,
#  'نری': 3611,
#  'اوئے': 441,
#  'گمشدہ': 5060,
#  'کتورے': 4620,
#  'اوہ': 466,
#  'اک': 503,
#  'پورا': 4112,
#  'میگزین': 3544,
#  'شکل': 2498,
#  'دیکھ': 1877,
#  'آئینے': 33,
#  'سکتے': 2343,
#  'توآپکا': 1204,
#  'اخلاقی': 195,
#  'فرض': 2761,
#  'خلاف': 1644,
#  'الزام': 321,
#  'لگائے': 3058,
#  'ئے': 139,
#  'بیشاب': 1032,
#  'آپکے': 120,
#  'صحیح': 2545,
#  'ھمارے': 5159,
#  'جانبازوں': 1298,
#  'آپکی': 119,
#  'چیخیں': 4453,
#  'گئ': 4975,
#  'قاتل': 2846,
#  'حل': 1542,
#  'اکٹھے': 512,
#  'باندھ': 632,
#  'بیس': 1030,
#  'میل': 3530,
#  'دور': 1800,
#  'سمندر': 2257,
#  'پھینک': 4201,
#  'کتیا': 4624,
#  'ہیرا': 5325,
#  'منڈی': 3446,
#  'گزارتی': 5032,
#  'ضلع': 2572,
#  'باجوڑ': 600,
#  'تعلق': 1166,
#  'نوجوان': 3681,
#  'ناران': 3563,
#  'کاغان': 4576,
#  'سیر': 2384,
#  'کیلئے': 4926,
#  'جارہے': 1289,
#  'راستے': 1931,
#  'کار': 4551,
#  'حادثے': 1478,
#  'شکار': 2491,
#  'حضرت': 1532,
#  'داتا': 1689,
#  'گنج': 5065,
#  'بخش': 680,
#  'رحمتہ': 1951,
#  'فرمان': 2773,
#  'عاجزی': 2609,
#  'تکبر': 1225,
#  'نفس': 3647,
#  'فریب': 2783,
#  'سپریم': 2327,
#  'کورٹ': 4792,
#  'نااہل': 3554,
#  'شخص': 2447,
#  'ڈی': 4528,
#  'فیکٹو': 2840,
#  'فرائض': 2751,
#  'انجام': 379,
#  'سال': 2147,
#  'اٹالین': 471,
#  'گورنمنٹ': 5086,
#  'کوئ': 4781,
#  'غفور': 2707,
#  'دیکھا': 1878,
#  'لکھتا': 3044,
#  'سیالکوٹ': 2371,
#  'جوتوں': 1418,
#  'سیزن': 2387,
#  'چل': 4329,
#  'پڑا': 4156,
#  'سلسلے': 2235,
#  'بسنے': 743,
#  'مائیں': 3114,
#  'بہنیں': 1018,
#  'آتیں': 43,
#  'شہر': 2508,
#  'لوٹ': 2996,
#  'بلاول': 764,
#  'بغیرت': 753,
#  'غیرت': 2722,
#  'مسلمانوں': 3310,
#  'قتل': 2862,
#  'عام': 2616,
#  'دوسری': 1814,
#  'عظیم': 2645,
#  'ہٹلر': 5313,
#  'مسولینی': 3312,
#  'یہودیوں': 5390,
#  'بل': 756,
#  'گھس': 5112,
#  'جانا': 1295,
#  'چاہیے': 4318,
#  'ڈوب': 4514,
#  'مقام': 3372,
#  'پائن': 3977,
#  'تسی': 1148,
#  'دونگا': 1818,
#  'حرامیوں': 1516,
#  'بھڑوا': 977,
#  'ظلم': 2606,
#  'ماتا': 3116,
#  'بیٹی': 1068,
#  'بیچ': 1072,
#  'تربیت': 1138,
#  'چلتا': 4336,
#  'تخم': 1134,
#  'انڈین': 422,
#  'چاہتے': 4312,
#  'عزت': 2635,
#  'سمجهتے': 2247,
#  'هيں': 3769,
#  'دوسروں': 1813,
#  'حالیہ': 1488,
#  'بارشوں': 609,
#  'حالات': 1484,
#  'سارے': 2143,
#  'ڈھٹائی': 4525,
#  'چادر': 4281,
#  'اوڑھ': 465,
#  'غیرتی': 2726,
#  'نیند': 3738,
#  'جھریوں': 1435,
#  'لوڑے': 3005,
#  'لکھنا': 3046,
#  'سیکھ': 2414,
#  'گت': 5001,
#  'سور': 2299,
#  'کمینے': 4761,
#  'ذلیل': 1907,
#  'لاشوں': 2923,
#  'انصاف': 408,
#  'بلوچستان': 774,
#  'کلبھوشن': 4732,
#  'گرفتاری': 5021,
#  'مجرم': 3191,
#  'قرار': 2869,
#  'اسکی': 257,
#  'شیخ': 2517,
#  'رشید': 1964,
#  'ماری': 3136,
#  'ہوگی': 5303,
#  'مہاجروں': 3509,
#  'غیر': 2721,
#  'مہاجر': 3508,
#  'شامل': 2438,
#  'ہوگئے': 5299,
#  'کاٹنے': 4602,
#  'ہمت': 5247,
#  'رنڈیوں': 1978,
#  'خاندان': 1599,
#  'فرد': 2757,
#  'چودی': 4375,
#  'غلطی': 2713,
#  'میر': 3525,
#  'الٹا': 341,
#  'لٹکانا': 3020,
#  'کنجھر': 4770,
#  'خسرے': 1632,
#  'روڈ': 2004,
#  'بیٹا': 1060,
#  'باب': 590,
#  'اتنی': 161,
#  'ہمدردی': 5250,
#  'بندہ': 816,
#  'امی': 358,
#  'قطری': 2885,
#  'خیال': 1679,
#  'کان': 4595,
#  'شا': 2427,
#  'چاند': 4288,
#  'پہنچ': 4214,
#  'لوگ': 3008,
#  'مہنگائی': 3515,
#  'ست': 2174,
#  'درگور': 1739,
#  'بچوں': 883,
#  'دفع': 1758,
#  'ہاہا': 5212,
#  'فکر': 2826,
#  'بولے': 857,
#  'چیز': 4454,
#  'یکجہتی': 5385,
#  'ہوۓ': 5308,
#  'گندگی': 5071,
#  'بدبو': 684,
#  'امید': 359,
#  'سکتی': 2342,
#  'گرین': 5030,
#  'پاسپورٹ': 3993,
#  'عبرت': 2622,
#  'نشان': 3622,
#  'میکسیکو': 3543,
#  'برازیل': 710,
#  'پاکستانی': 4013,
#  'خاتون': 1585,
#  'ھر': 5154,
#  'لاھور': 2940,
#  'مانگتا': 3157,
#  'ھوئی': 5163,
#  'زلیل': 2095,
#  'انیل': 439,
#  'مسرت': 3304,
#  'حرکت': 1517,
#  'جرت': 1350,
#  'پاپوش': 4008,
#  'اینکرز': 564,
#  'مبارکباد': 3171,
#  'مستحق': 3298,
#  'کےپیروڈی': 4970,
#  'ٹائپ': 3896,
#  'تبصروں': 1118,
#  'دکھایا': 1833,
#  'اجتک': 171,
#  'کرسکی': 4663,
#  'چوتیے': 4365,
#  'بیچا': 1073,
#  'گنجے': 5068,
#  'ناندیڑ': 3580,
#  'ٹریکٹرحادثہ': 3910,
#  'کاشکار': 4575,
#  'ڈارئیورسید': 4469,
#  'قاسم': 2851,
#  'دوافراد': 1797,
#  'لندن': 2974,
#  'کھسرا': 4855,
#  'چوراہے': 4379,
#  'کھڑا': 4882,
#  'بیڑا': 1078,
#  'غرق': 2700,
#  'سفاکیت': 2223,
#  'ممالک': 3409,
#  'کونسے': 4807,
#  'محترمہ': 3206,
#  'کھوتا': 4868,
#  'کھانے': 4851,
#  'پٹواری': 4141,
#  'سمجھ': 2248,
#  'یقین': 5358,
#  'ابا': 142,
#  'جی': 1458,
#  'فرما': 2766,
#  'پشتون': 4077,
#  'مند': 3435,
#  'انکے': 432,
#  'وفاداری': 3845,
#  'اسکو': 255,
#  'ملانا': 3391,
#  'منا': 3416,
#  'چوکیوں': 4401,
#  'نشانہ': 3623,
#  'بنایا': 801,
#  'ہندوستانی': 5259,
#  'حد': 1501,
#  'تبصرہ': 1119,
#  'کریں': 4704,
#  'خاموش': 1596,
#  'بندوقوں': 813,
#  'توپوں': 1214,
#  'لونڈے': 2994,
#  'کمائی': 4742,
#  'پیدا': 4234,
#  'مثال': 3181,
#  'اچھے': 499,
#  'قائم': 2843,
#  'ہیجڑا': 5321,
#  'ٹھگوں': 3956,
#  'جوڑی': 1424,
#  'ہجڑہ': 5221,
#  'اقوام': 309,
#  'متحدہ': 3177,
#  'مستقل': 3301,
#  'مندوب': 3436,
#  'سید': 2377,
#  'اکبرالدین': 508,
#  'جھوٹوں': 1440,
#  'سردار': 2187,
#  'نکلا': 3704,
#  'پٹواریوں': 4143,
#  'لفافہ': 2961,
#  'صح': 2538,
#  'کشیدگی': 4722,
#  'درد': 1728,
#  'فلسطینی': 2799,
#  'ریلی': 2055,
#  'چونچ': 4389,
#  'رکھو': 2019,
#  'ہندووں': 5260,
#  'ٹیپو': 3966,
#  'سلطان': 2236,
#  'چکے': 4416,
#  'ماوں': 3162,
#  'گر': 5009,
#  'جایا': 1329,
#  'حضور': 1533,
#  'فرمایا': 2774,
#  'جنگوں': 1403,
#  'آغاز': 75,
#  'تعالی': 1162,
#  'عجمیوں': 2626,
#  'لشکر': 2952,
#  'اٹھائے': 475,
#  'بہترہن': 1013,
#  'سوار': 2290,
#  'گند': 5069,
#  'اٹھاؤ': 474,
#  'بھڑوے': 982,
#  'دماغ': 1785,
#  'پیدل': 4237,
#  'ارسطو': 216,
#  'عمران': 2668,
#  'سرکار': 2196,
#  'سالمعیشت': 2149,
#  'قرضوں': 2874,
#  'انبار': 367,
#  'دوستوں': 1809,
#  'موڑ': 3482,
#  'قادیانی': 2849,
#  'کافر': 4577,
#  'مرتد': 3249,
#  'بتائے': 651,
#  'قمر': 2890,
#  'بکنے': 911,
#  'سینیٹرز': 2401,
#  'بنانے': 798,
#  'اعلان': 281,
#  'اسکا': 254,
#  'ظالم': 2601,
#  'ہمیشہ': 5253,
#  'صفحہ': 2554,
#  'ہستی': 5231,
#  'مٹے': 3490,
#  'تاریخ': 1102,
#  'تھو': 1236,
#  'کررہی': 4658,
#  'ضمن': 2573,
#  'بلند': 769,
#  'اربوں': 213,
#  'کھا': 4845,
#  'ترس': 1142,
#  'ارہا': 221,
#  'یورپ': 5372,
#  'پھانسی': 4182,
#  'جج': 1344,
#  'بلیک': 781,
#  'لڑکیوں': 3036,
#  'رو': 1982,
#  'پوچھتے': 4127,
#  'گندا': 5070,
#  'لفظ': 2964,
#  'استعمال': 230,
#  'شمار': 2474,
#  'ننے': 3668,
#  'برے': 732,
#  'جرنیل': 1354,
#  'جاہل': 1326,
#  'کم': 4741,
#  'ظرف': 2605,
#  'ہوتے': 5278,
#  'صورتحال': 2564,
#  'سنگینی': 2281,
#  'نزاکت': 3614,
#  'اندازہ': 384,
#  'ساڈھے': 2162,
#  'تے': 1265,
#  'ٹھ': 3945,
#  'مولوی': 3470,
#  'وی': 3872,
#  'گمراہ': 5059,
#  'ھو': 5162,
#  'سےکشمیر': 2424,
#  'سودا': 2294,
#  'امریکہ': 353,
#  'پیسوں': 4244,
#  'حج': 1496,
#  'گٸ': 5101,
#  'ایجنٹ': 543,
#  'لسانیت': 2950,
#  'رھی': 2031,
#  'ھیں': 5190,
#  'سوچا': 2310,
#  'مخالفین': 3219,
#  'حال': 1483,
#  'جوس': 1421,
#  'خالی': 1595,
#  'ﮈبے': 5396,
#  'پٹاخہ': 4136,
#  'بجائیں': 663,
#  'قینچی': 2906,
#  'قطرے': 2886,
#  'مزید': 3291,
#  'حاصل': 1479,
#  'نطفے': 3634,
#  'چوری': 4382,
#  'نوابشاہ': 3675,
#  'ایل': 555,
#  'کرارا': 4631,
#  'سالہ': 2153,
#  'گینڈے': 5140,
#  'ڈالو': 4477,
#  'پاکستانيوں': 4012,
#  'کالا': 4581,
#  'کردیا': 4650,
#  'ننگی': 3666,
#  'تصاویر': 1154,
#  'دلا': 1766,
#  'کہوں': 4903,
#  'چوکی': 4398,
#  'شاہین': 2445,
#  'بیغرت': 1037,
#  'برگیڈ': 725,
#  'نوکری': 3689,
#  'عید': 2687,
#  'چھٹی': 4437,
#  'بک': 903,
#  'سودے': 2298,
#  'غزنی': 2705,
#  'وردک': 3818,
#  'فضائی': 2789,
#  'حملوں': 1549,
#  'تصادم': 1153,
#  'دوران': 1801,
#  'طالبان': 2583,
#  'عسکریت': 2641,
#  'پسندوں': 4072,
#  'بھاری': 926,
#  'اٹھانا': 478,
#  'حیاء': 1574,
#  'کہیں': 4906,
#  'جگہ': 1432,
#  ...}

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, dataset['target'], test_size=0.15, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %%
from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,pred)
print("Complete Dataset Results")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# Complete Dataset Results
# confusion matrix
# [[171  20]
#  [ 41 128]]
# Accuracy score: 0.8305555555555556
# Precision score: 0.8357343192248853
# F1 score: 0.8281031068249955
# Recall score: 0.8263422039096626

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %%
from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,pred)
print("----------------Test Train Score Complete Datasets---------------")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# ----------------Test Train Score Complete Datasets---------------
# confusion matrix
# [[152  39]
#  [ 32 137]]
# Accuracy score: 0.8027777777777778
# Precision score: 0.802248023715415
# F1 score: 0.8024347826086956
# Recall score: 0.8032312029492858

# %%
from sklearn.svm import SVC
classifier=SVC(probability=True)
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %%
cm=confusion_matrix(y_test,pred)
print("Complete Dataset Score")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
# Out:
# Complete Dataset Score
# confusion matrix
# [[170  21]
#  [ 40 129]]
# Accuracy score: 0.8305555555555556
# Precision score: 0.8347619047619048
# F1 score: 0.8283288643594775

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %%
cm=confusion_matrix(y_test,pred)
print("Complete Dataset Results")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# Complete Dataset Results
# confusion matrix
# [[113  78]
#  [ 45 124]]
# Accuracy score: 0.6583333333333333
# Precision score: 0.6645256297781676
# F1 score: 0.6580140408869393
# Recall score: 0.6626754236500512

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %%
cm=confusion_matrix(y_test,pred)
print("confusion matrix")
print("Complete Dataset Results")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# confusion matrix
# Complete Dataset Results
# [[165  26]
#  [ 37 132]]
# Accuracy score: 0.825
# Precision score: 0.8261373605715001
# F1 score: 0.8235170530149171
# Recall score: 0.8224697171535673
