# %% [markdown]
# **Importing pandas here**

# %%
import pandas as pd

# %% [markdown]
# **Importing dataset and Having a look at dataset**

# %%
train=pd.read_csv("Dataset 1.csv")
test=pd.read_csv("Dataset 2.csv")
stopw=pd.read_csv("Stopword.csv")
test=test[['tweet','target']]
test.head()
# Out:
#                                                tweet  target
# 0                             کہ کے لے لی شام دلے کی       1
# 1  اب اگر اس نے کچھ جواب دیا تو اس کی گانڈ مار دی...       1
# 2  اب ان چوتیوں نے وہ جو کنسرٹ ہو رہا تھا وہ بھی ...       1
# 3  اب ان کی گانڈ میں ہاتھ ڈال کر انتڑیاں نکالے گا...       1
# 4                      اب تک سکی سب سے اچھی ویڈیو ہے       0

# %% [markdown]
# ### Dataset Cleaning process
# 1. Remove Missing values

# %%
nan_value = float("NaN")
train.replace("", nan_value, inplace=True)
train.dropna(subset = ["tweet"], inplace=True)
train.tail()
print(train['target'].value_counts())
nan_value = float("NaN")
test.replace("", nan_value, inplace=True)
test.dropna(subset = ["tweet"], inplace=True)
test.tail()
print(test['target'].value_counts())
# Out:
# 0    1213
# 1    1187
# Name: target, dtype: int64
# 1    1108
# 0    1062
# Name: target, dtype: int64

# %% [markdown]
# ### Dataset Cleaning process
# 2. Acquring Stopwords

# %%
stopwords=[]
for i in (stopw['Stopwords']):
    stopwords.append(i)

# %% [markdown]
# ### Dataset Cleaning process
# 1. Remove Missing values
# 2. Tokenization
# 3. Cleaning Extra Characters
# 4. Removal of Stopwords

# %%
from urduhack.preprocessing import remove_punctuation
from urduhack.preprocessing import remove_accents
tain_corpus=[]
for i in (train['tweet']):
        i=remove_punctuation(i)
        i=remove_accents(i)
        review=i.split()
        review=[word for word in review if word not in stopwords]
        review=' '.join(review)
        tain_corpus.append(review)
test_corpus=[]
for i in (test['tweet']):
        i=remove_punctuation(i)
        i=remove_accents(i)
        review=i.split()
        review=[word for word in review if word not in stopwords]
        review=' '.join(review)
        test_corpus.append(review)

# %% [markdown]
# ### Feature Extraction
# 1. **TFIDF** Term Frequency Inverse Document Frequencey
# 2. Looking at vocubalary

# %%
from sklearn.feature_extraction.text import CountVectorizer    
train_vectorizer=CountVectorizer(max_features=10000)
# from sklearn.feature_extraction.text import TfidfVectorizer
max_feature_num = 10000
train_vectorizer = CountVectorizer(max_features=max_feature_num)
X_train=train_vectorizer.fit_transform(tain_corpus).toarray()
y_train=train['target']
train_vectorizer.vocabulary_
test_vectorizer = CountVectorizer(max_features=max_feature_num,vocabulary=train_vectorizer.vocabulary_)
X_test=test_vectorizer.fit_transform(test_corpus).toarray()
y_test=test['target']
train_vectorizer.vocabulary_
# Out:
# {'قوم': 2856,
#  'پرانے': 3971,
#  'خاندانی': 1578,
#  'نمک': 3611,
#  'حرام': 1481,
#  'خنزیروں': 1627,
#  'بغض': 737,
#  'نواز': 3625,
#  'سپورٹ': 2295,
#  'پاکستان': 3943,
#  'قبضے': 2821,
#  'اسرائیلی': 231,
#  'پائلٹ': 3907,
#  'شریف': 2429,
#  'نواسہ': 3628,
#  'مستقبل': 3253,
#  'وزیر': 3768,
#  'اعظم': 272,
#  'ٹویٹر': 3864,
#  'پہ': 4140,
#  'بکواس': 901,
#  'آسان': 68,
#  'کشمیوں': 4650,
#  'مشکل': 3270,
#  'وقت': 3788,
#  'تنہا': 1188,
#  'چھوڑے': 4372,
#  'جبکہ': 1319,
#  'سندھیوں': 2237,
#  'بلوچوں': 761,
#  'پشتونوں': 4012,
#  'زندہ': 2067,
#  'مادرچود': 3072,
#  'یوتھئے': 5292,
#  'کشمیر': 4645,
#  'ہاتھہ': 5125,
#  'نکل': 3650,
#  'ثالثی': 1256,
#  'نیازی': 3677,
#  'واہ': 3748,
#  'کررہے': 4592,
#  'بھوسڑی': 944,
#  'گانڈو': 4912,
#  'بیچنے': 1065,
#  'کتو': 4553,
#  'عالمی': 2577,
#  'سازش': 2108,
#  'ہمارےسلیکٹڈ': 5166,
#  'سلیکٹرز': 2205,
#  'کےمنہ': 4891,
#  'سعودی': 2182,
#  'عرب': 2594,
#  'شرمناک': 2419,
#  'طمانچہ': 2555,
#  'کتی': 4558,
#  'بچے': 878,
#  'گھٹیا': 5047,
#  'پیداوار': 4172,
#  'بہتر': 1000,
#  'انکو': 418,
#  'گھر': 5031,
#  'بھیج': 982,
#  'کنجروں': 4699,
#  'موجیں': 3415,
#  'نیب': 3678,
#  'ڈرامہ': 4430,
#  'آج': 42,
#  'دل': 1743,
#  'خدا': 1592,
#  'قسم': 2839,
#  'خون': 1654,
#  'آنسو': 99,
#  'رویا': 1978,
#  'قبرستان': 2818,
#  'قبروں': 2819,
#  'حالت': 1463,
#  'دیکھی': 1859,
#  'لعنت': 2912,
#  'ٹوٹ': 3857,
#  'شرمی': 2422,
#  'انتہا': 365,
#  'اندر': 376,
#  'رنڈی': 1943,
#  'وآپس': 3715,
#  'عوام': 2639,
#  'جہاں': 1433,
#  'نظر': 3586,
#  'پکڑ': 4108,
#  'گانڈ': 4911,
#  'کیڑا': 4868,
#  'مارے': 3091,
#  'جاو': 1292,
#  'جاکر': 1298,
#  'کشمیریوں': 4649,
#  'ساتھ': 2094,
#  'مل': 3334,
#  'جنگ': 1380,
#  'جنرل': 1374,
#  'باجوہ': 588,
#  'نام': 3524,
#  'سن': 2226,
#  'مودی': 3416,
#  'ٹانگیں': 3832,
#  'کانپتی': 4533,
#  'آرمی': 58,
#  'چیف': 4393,
#  'پلوامہ': 4022,
#  'بھارتی': 913,
#  'فوج': 2771,
#  'ڈنڈا': 4445,
#  'کیسی': 4850,
#  'خبیث': 1590,
#  'انسان': 386,
#  'جسکے': 1344,
#  'مرنے': 3218,
#  'ہمیں': 5175,
#  'خوشی': 1649,
#  'لعنتی': 2913,
#  'پتا': 3953,
#  'کب': 4541,
#  'مرے': 3230,
#  'کتے': 4560,
#  'موت': 3409,
#  'شروع': 2424,
#  'برا': 693,
#  'لگتا': 3028,
#  'زندگی': 2066,
#  'پہلا': 4146,
#  'ووٹ': 3796,
#  'بار': 594,
#  'سلیکشن': 2204,
#  'گورایہ': 5006,
#  'گٹر': 5025,
#  'فوجیستان': 2773,
#  'بس': 726,
#  'کام': 4521,
#  'ھےالطاف': 5113,
#  'بھائی': 909,
#  'کےاوپر': 4875,
#  'پابندی': 3914,
#  'تالا': 1092,
#  'ڈال': 4406,
#  'مریم': 3228,
#  'احتساب': 175,
#  'عدالت': 2590,
#  'بلا': 743,
#  'سیکنڈز': 2372,
#  'دن': 1768,
#  'ریمانڈ': 2026,
#  'دلوانا': 1753,
#  'تیز': 1246,
#  'ترین': 1135,
#  'کاروائی': 4490,
#  'پارلمنٹ': 3918,
#  'بلڈنگ': 762,
#  'بھیک': 994,
#  'بنا': 771,
#  'بند': 796,
#  'گھسرا': 5036,
#  'گھسرے': 5037,
#  'مزہ': 3242,
#  'آۓ': 133,
#  'بھول': 946,
#  'لوگوں': 2966,
#  'زبان': 2045,
#  'بشری': 732,
#  'پیرنی': 4175,
#  'کہاں': 4824,
#  'بنی': 817,
#  'گالہ': 4906,
#  'کتوں': 4557,
#  'لاکھوں': 2897,
#  'مظلوم': 3288,
#  'ممتاز': 3365,
#  'ماں': 3118,
#  'پھودی': 4126,
#  'حرامی': 1492,
#  'بلوایا': 757,
#  'میکاسنگھ': 3495,
#  'انڈیا': 408,
#  'کرنٹ': 4608,
#  'اکاؤنٹ': 494,
#  'خسارہ': 1608,
#  'کمی': 4685,
#  'کامیابی': 4528,
#  'وزیراعظم': 3769,
#  'خاتمہ': 1562,
#  'انشاءلله': 394,
#  'خود': 1639,
#  'سندھی': 2236,
#  'بولتا': 839,
#  'ھے': 5111,
#  'فخر': 2711,
#  'بلوچ': 758,
#  'ھونے': 5091,
#  'بلوچست': 759,
#  'کاش': 4507,
#  'اج': 163,
#  'موچھیں': 3435,
#  'کاٹ': 4534,
#  'پچھواڑا': 4086,
#  'پھاڑ': 4118,
#  'بھیجیں': 989,
#  'طوفانی': 2561,
#  'بارش': 595,
#  'تباہی': 1105,
#  'مچا': 3446,
#  'سینکڑوں': 2360,
#  'مکانات': 3456,
#  'نقصان': 3599,
#  'سیلابی': 2355,
#  'ریلے': 2025,
#  'محصور': 3161,
#  'محترم': 3156,
#  'جناب': 1367,
#  'انکل': 417,
#  'باجرہ': 585,
#  'ایکسٹینشن': 567,
#  'ٹیوٹ': 3896,
#  'قیامت': 2862,
#  'آگئی': 126,
#  'تھیآپ': 1231,
#  'نظریات': 3587,
#  'پہرہ': 4144,
#  'کمینی': 4690,
#  'منہ': 3405,
#  'رکھ': 1987,
#  'سچ': 2297,
#  'حق': 1512,
#  'بولنے': 844,
#  'لکھنے': 3005,
#  'نڈر': 3642,
#  'بیوروچیف': 1042,
#  'ٹرائیبل': 3840,
#  'ٹائمز': 3829,
#  'ڈسٹرک': 4444,
#  'ویسٹ': 3813,
#  'بلدیہ': 754,
#  'ٹاون': 3834,
#  'کراچی': 4570,
#  'میںشہید': 3500,
#  'اوقات': 443,
#  'مادر': 3070,
#  'چود': 4302,
#  'like': 13,
#  'خنزیر': 1625,
#  'اولاد': 446,
#  'جتنا': 1321,
#  'ملک': 3355,
#  'جان': 1277,
#  'بات': 581,
#  'مزاق': 3237,
#  'بھگوڑی': 979,
#  'لیگ': 3057,
#  'پورے': 4049,
#  'کشمیروں': 4646,
#  'علاوہ': 2618,
#  'چھوڑ': 4368,
#  'غلط': 2675,
#  'برگہ': 711,
#  'کشتہ': 4643,
#  'روز': 1958,
#  'اول': 444,
#  'طبیعت': 2550,
#  'صاف': 2495,
#  'چاہئیے': 4245,
#  'لعنتییوں': 2916,
#  'سیاست': 2330,
#  'لیکر': 3056,
#  'اسٹیبلشمنٹ': 243,
#  'کیسیس': 4851,
#  'کالے': 4520,
#  'کرتوتوں': 4575,
#  'بچاتے': 864,
#  'بہن': 1003,
#  'قومی': 2858,
#  'اثاثے': 161,
#  'برباد': 700,
#  'رھا': 1997,
#  'موقع': 3420,
#  'چمکانے': 4280,
#  'نسل': 3564,
#  'شرم': 2417,
#  'ابے': 147,
#  'مار': 3074,
#  'چودوں': 4309,
#  'یار': 5272,
#  'افغانیوں': 292,
#  'چدائی': 4260,
#  'سفید': 2189,
#  'پتہ': 3960,
#  'ڈرا': 4428,
#  'غلیظ': 2677,
#  'بیان': 1010,
#  'حکومت': 1548,
#  'پکڑتے': 4110,
#  'پاک': 3941,
#  'لائن': 2873,
#  'آف': 74,
#  'کنٹرول': 4706,
#  'اشتعال': 256,
#  'انگیزی': 427,
#  'توڑ': 1203,
#  'جواب': 1390,
#  'کارروائی': 4485,
#  'افسر': 282,
#  'سمیت': 2222,
#  'فوجی': 2772,
#  'ہلاک': 5158,
#  'ایس': 539,
#  'پی': 4159,
#  'آر': 55,
#  'سوگوار': 2279,
#  'اتنے': 158,
#  'کنجری': 4700,
#  'گشتی': 4967,
#  'دلے': 1762,
#  'جھولی': 1416,
#  'بیٹھ': 1050,
#  'زراہ': 2055,
#  'غور': 2681,
#  'تیرا': 1244,
#  'بھونکنا': 953,
#  'ہوگا': 5214,
#  'ہتھے': 5139,
#  'مر': 3192,
#  'جاۓ': 1316,
#  'عبدالقدیر': 2582,
#  'خان': 1575,
#  'کارگل': 4500,
#  'دہلی': 1838,
#  'منٹ': 3398,
#  'بٹن': 855,
#  'کلک': 4666,
#  'تباہ': 1101,
#  'کرسکتے': 4595,
#  'تھےیہ': 1235,
#  'لکھتے': 3003,
#  'ریے': 2035,
#  'حلال': 1520,
#  'زادے': 2041,
#  'شک': 2450,
#  'کارتک': 4484,
#  'اچھی': 488,
#  'خاصی': 1569,
#  'چکی': 4352,
#  'کمنٹس': 4681,
#  'لہذا': 3040,
#  'کہوںگا': 4833,
#  'بریکنگ': 718,
#  'نیوز': 3685,
#  'اچانک': 481,
#  'شاندار': 2403,
#  'زرداری': 2056,
#  'اینڈ': 551,
#  'کمپنی': 4683,
#  'کمر': 4677,
#  'خبر': 1587,
#  'پاگل': 3950,
#  'زرا': 2052,
#  'سنبھال': 2230,
#  'بدکردار': 688,
#  'باپ': 626,
#  'واشل': 3728,
#  'گدھا': 4923,
#  'راگنی': 1913,
#  'خوروں': 1643,
#  'گدھی': 4924,
#  'بچو': 871,
#  'لگ': 3011,
#  'باری': 599,
#  'لال': 2883,
#  'مرچیں': 3223,
#  'لڑتی': 2984,
#  'گائے': 4902,
#  'پیشاپ': 4185,
#  'پینے': 4196,
#  'گندی': 4996,
#  'کشمیری': 4648,
#  'اللہ': 321,
#  'لاکھ': 2896,
#  'شکر': 2455,
#  'اداکرتے': 199,
#  'ضمیر': 2536,
#  'فروشوں': 2742,
#  'پاکستانیوں': 3947,
#  'چھوٹی': 4365,
#  'علماء': 2621,
#  'کرام': 4568,
#  'آقا': 84,
#  'علیہ': 2627,
#  'السلام': 313,
#  'وارث': 3724,
#  'حثیت': 1472,
#  'بارے': 600,
#  'ٹیکسی': 3901,
#  'لاوارث': 2889,
#  'دنیا': 1770,
#  'بہترین': 1002,
#  'ہتھیار': 5137,
#  'ایمانداری': 547,
#  'تلوار': 1170,
#  'دیانتداری': 1839,
#  'بچی': 875,
#  'خور': 1642,
#  'جھنڈے': 1415,
#  'ناپاک': 3533,
#  'مت': 3127,
#  'شیر': 2482,
#  'کہتے': 4826,
#  'کتا': 4543,
#  'حضرات': 1508,
#  'مسلم': 3261,
#  'امہ': 348,
#  'سحانے': 2142,
#  'خواب': 1632,
#  'دیکھتے': 1854,
#  'جاگ': 1299,
#  'پوری': 4048,
#  'امت': 341,
#  'میٹرو': 3489,
#  'پشاور': 4009,
#  'لیگی': 3058,
#  'میڈیا': 3493,
#  'ٹیم': 3892,
#  'پھڈے': 4130,
#  'جاری': 1273,
#  'کنجر': 4695,
#  'بیغیرت': 1028,
#  'بیغیرتوں': 1030,
#  'دردی': 1707,
#  'لوٹا': 2953,
#  'پن': 4029,
#  'گاڑی': 4916,
#  'لیٹا': 3052,
#  'سوات': 2253,
#  'دوسرے': 1793,
#  'وزیرستانی': 3771,
#  'بن': 770,
#  'دلال': 1745,
#  'بنےگا': 822,
#  'یارب': 5273,
#  'العزت': 315,
#  'شہ': 2464,
#  'رگ': 1996,
#  'جلدازجلد': 1355,
#  'بھارت': 911,
#  'قابض': 2805,
#  'افواج': 294,
#  'آزادی': 66,
#  'نصیب': 3581,
#  'فرماء': 2729,
#  'آمی': 94,
#  'بوری': 835,
#  'ادارے': 195,
#  'وجہ': 3751,
#  'بھونک': 950,
#  'بےغیرت': 1079,
#  'حاجی': 1453,
#  'جامل': 1276,
#  'حالتی': 1464,
#  'انتقال': 363,
#  'کرگئے': 4630,
#  'نماز': 3606,
#  'جنازہ': 1369,
#  'گیارہ': 5053,
#  'بجے': 660,
#  'نڑیل': 3643,
#  'پیر': 4174,
#  'ادا': 192,
#  'جائےگی': 1266,
#  'ٹھوکو': 3883,
#  'ویسے': 3815,
#  'مرواتے': 3221,
#  'تع': 1150,
#  'مشہور': 3273,
#  'زمانہ': 2060,
#  'بےغیرتوں': 1081,
#  'پہچان': 4157,
#  'دوستو': 1785,
#  'قابل': 2806,
#  'اسکے': 253,
#  'سنو': 2240,
#  'حافظ': 1460,
#  'بلاتحقیق': 745,
#  'خارجہ': 1567,
#  'کہنے': 4830,
#  'دشنام': 1727,
#  'طرازی': 2551,
#  'سر': 2144,
#  'جوابي': 1392,
#  'كارواي': 2868,
#  'نهى': 3618,
#  'انكو': 401,
#  'سبق': 2132,
#  'سكها': 2191,
#  'دينا': 1802,
#  'بہنوں': 1005,
#  'بیٹیوں': 1058,
#  'جیل': 1445,
#  'بھیجتی': 985,
#  'سیدھا': 2343,
#  'گولی': 5018,
#  'مارتے': 3079,
#  'کوس': 4723,
#  'ہورہاہے': 5200,
#  'چور': 4314,
#  'چایئے': 4257,
#  'سزا': 2168,
#  'رات': 1891,
#  'کٹ': 4758,
#  'ہات': 5122,
#  'ہولناک': 5205,
#  'خبریں': 1589,
#  'پڑھ': 4100,
#  'گھنٹوں': 5040,
#  'اداس': 196,
#  'حیا': 1551,
#  'معصوم': 3307,
#  'الگ': 333,
#  'گیراج': 5056,
#  'گرفتار': 4939,
#  'کھوتی': 4801,
#  'پرانی': 3970,
#  'عادتیں': 2574,
#  'خاموشی': 1574,
#  'اختیار': 187,
#  'کرلیتا': 4603,
#  'مسلمان': 3262,
#  'ضیاء': 2538,
#  'جشن': 1347,
#  'منارہے': 3375,
#  'نظریاتی': 3588,
#  'سرحدوں': 2148,
#  'اشد': 258,
#  'ضرورت': 2532,
#  'بیشک': 1022,
#  'ھم': 5076,
#  'گناہگار': 4987,
#  'سیاہکار': 2337,
#  'دیکھیں': 1860,
#  'حامد': 1467,
#  'ماضی': 3095,
#  'ایکسٹنشنز': 566,
#  'نری': 3560,
#  'اوئے': 430,
#  'گمشدہ': 4983,
#  'کتورے': 4555,
#  'اوہ': 454,
#  'اک': 493,
#  'پورا': 4046,
#  'میگزین': 3497,
#  'شکل': 2459,
#  'دیکھ': 1849,
#  'آئینے': 32,
#  'سکتے': 2307,
#  'توآپکا': 1191,
#  'اخلاقی': 191,
#  'فرض': 2723,
#  'خلاف': 1621,
#  'الزام': 312,
#  'لگائے': 3015,
#  'ئے': 136,
#  'بیشاب': 1020,
#  'آپکے': 118,
#  'صحیح': 2507,
#  'ھمارے': 5078,
#  'جانبازوں': 1281,
#  'آپکی': 117,
#  'چیخیں': 4389,
#  'گئ': 4900,
#  'قاتل': 2807,
#  'حل': 1519,
#  'اکٹھے': 502,
#  'باندھ': 619,
#  'بیس': 1018,
#  'میل': 3483,
#  'دور': 1778,
#  'سمندر': 2221,
#  'پھینک': 4137,
#  'کتیا': 4559,
#  'ہیرا': 5238,
#  'منڈی': 3400,
#  'گزارتی': 4952,
#  'ضلع': 2534,
#  'باجوڑ': 587,
#  'تعلق': 1155,
#  'نوجوان': 3629,
#  'ناران': 3515,
#  'کاغان': 4509,
#  'سیر': 2347,
#  'کیلئے': 4853,
#  'جارہے': 1272,
#  'راستے': 1901,
#  'کار': 4483,
#  'حادثے': 1456,
#  'شکار': 2452,
#  'حضرت': 1509,
#  'داتا': 1667,
#  'گنج': 4988,
#  'بخش': 667,
#  'رحمتہ': 1920,
#  'فرمان': 2735,
#  'عاجزی': 2571,
#  'تکبر': 1211,
#  'نفس': 3597,
#  'فریب': 2745,
#  'سپریم': 2291,
#  'کورٹ': 4721,
#  'نااہل': 3506,
#  'شخص': 2409,
#  'ڈی': 4462,
#  'فیکٹو': 2801,
#  'فرائض': 2713,
#  'انجام': 369,
#  'سال': 2110,
#  'اٹالین': 459,
#  'گورنمنٹ': 5009,
#  'کوئ': 4711,
#  'غفور': 2670,
#  'دیکھا': 1850,
#  'لکھتا': 3002,
#  'سیالکوٹ': 2334,
#  'جوتوں': 1397,
#  'سیزن': 2350,
#  'چل': 4265,
#  'پڑا': 4090,
#  'سلسلے': 2199,
#  'بسنے': 730,
#  'مائیں': 3066,
#  'بہنیں': 1006,
#  'آتیں': 41,
#  'شہر': 2469,
#  'لوٹ': 2952,
#  'بلاول': 750,
#  'بغیرت': 739,
#  'غیرت': 2684,
#  'مسلمانوں': 3263,
#  'قتل': 2823,
#  'عام': 2578,
#  'دوسری': 1792,
#  'عظیم': 2607,
#  'ہٹلر': 5226,
#  'مسولینی': 3265,
#  'یہودیوں': 5313,
#  'بل': 742,
#  'گھس': 5035,
#  'جانا': 1278,
#  'چاہیے': 4254,
#  'ڈوب': 4448,
#  'مقام': 3325,
#  'پائن': 3908,
#  'تسی': 1137,
#  'دونگا': 1796,
#  'حرامیوں': 1493,
#  'بھڑوا': 966,
#  'ظلم': 2568,
#  'ماتا': 3068,
#  'بیٹی': 1056,
#  'بیچ': 1060,
#  'تربیت': 1127,
#  'چلتا': 4272,
#  'تخم': 1124,
#  'انڈین': 411,
#  'چاہتے': 4249,
#  'عزت': 2597,
#  'سمجهتے': 2211,
#  'هيں': 3713,
#  'دوسروں': 1791,
#  'حالیہ': 1466,
#  'بارشوں': 596,
#  'حالات': 1462,
#  'سارے': 2106,
#  'ڈھٹائی': 4459,
#  'چادر': 4217,
#  'اوڑھ': 453,
#  'غیرتی': 2688,
#  'نیند': 3683,
#  'جھریوں': 1414,
#  'لوڑے': 2961,
#  'لکھنا': 3004,
#  'سیکھ': 2377,
#  'جگت': 1410,
#  'سور': 2263,
#  'کمینے': 4691,
#  'ذلیل': 1877,
#  'لاشوں': 2881,
#  'انصاف': 397,
#  'بلوچستان': 760,
#  'کلبھوشن': 4662,
#  'گرفتاری': 4941,
#  'مجرم': 3142,
#  'قرار': 2830,
#  'اسکی': 252,
#  'شیخ': 2478,
#  'رشید': 1933,
#  'ماری': 3088,
#  'ہوگی': 5217,
#  'مہاجروں': 3463,
#  'غیر': 2683,
#  'مہاجر': 3462,
#  'شامل': 2400,
#  'ہوگئے': 5213,
#  'کاٹنے': 4536,
#  'ہمت': 5168,
#  'رنڈیوں': 1947,
#  'خاندان': 1576,
#  'فرد': 2719,
#  'چودی': 4312,
#  'غلطی': 2676,
#  'میر': 3479,
#  'الٹا': 332,
#  'لٹکانا': 2976,
#  'کنجھر': 4701,
#  'خسرے': 1609,
#  'روڈ': 1973,
#  'بیٹا': 1048,
#  'باب': 577,
#  'اتنی': 157,
#  'ہمدردی': 5171,
#  'بندہ': 805,
#  'امی': 349,
#  'قطری': 2846,
#  'خیال': 1657,
#  'کان': 4529,
#  'شا': 2389,
#  'چاند': 4224,
#  'پہنچ': 4150,
#  'لوگ': 2964,
#  'مہنگائی': 3469,
#  'ست': 2137,
#  'درگور': 1717,
#  'بچوں': 872,
#  'دفع': 1736,
#  'ہاہا': 5133,
#  'فکر': 2788,
#  'بولے': 846,
#  'چیز': 4390,
#  'یکجہتی': 5309,
#  'ہوۓ': 5221,
#  'گندگی': 4994,
#  'بدبو': 671,
#  'امید': 350,
#  'سکتی': 2306,
#  'گرین': 4950,
#  'پاسپورٹ': 3924,
#  'عبرت': 2584,
#  'نشان': 3572,
#  'میکسیکو': 3496,
#  'برازیل': 697,
#  'پاکستانی': 3945,
#  'خاتون': 1563,
#  'ھر': 5073,
#  'لاھور': 2898,
#  'مانگتا': 3109,
#  'ھوئی': 5082,
#  'زلیل': 2059,
#  'انیل': 429,
#  'مسرت': 3257,
#  'حرکت': 1494,
#  'جرت': 1331,
#  'پاپوش': 3940,
#  'اینکرز': 553,
#  'مبارکباد': 3123,
#  'مستحق': 3251,
#  'کےپیروڈی': 4895,
#  'ٹائپ': 3831,
#  'تبصروں': 1108,
#  'دکھایا': 1811,
#  'اجتک': 167,
#  'کرسکی': 4596,
#  'چوتیے': 4301,
#  'بیچا': 1061,
#  'گنجے': 4991,
#  'ناندیڑ': 3531,
#  'ٹریکٹرحادثہ': 3845,
#  'کاشکارڈارئیورسید': 4508,
#  'قاسم': 2812,
#  'دوافراد': 1775,
#  'لندن': 2932,
#  'کھسرا': 4786,
#  'چوراہے': 4316,
#  'کھڑا': 4812,
#  'بیڑا': 1066,
#  'غرق': 2663,
#  'سفاکیت': 2187,
#  'ممالک': 3363,
#  'کونسے': 4737,
#  'محترمہ': 3157,
#  'کھوتا': 4799,
#  'کھانے': 4782,
#  'پٹواری': 4075,
#  'سمجھ': 2212,
#  'یقین': 5284,
#  'ابا': 139,
#  'جی': 1436,
#  'فرما': 2728,
#  'پشتون': 4010,
#  'مند': 3389,
#  'انکے': 421,
#  'وفاداری': 3784,
#  'اسکو': 250,
#  'ملانا': 3344,
#  'منا': 3370,
#  'چوکیوں': 4338,
#  'نشانہ': 3573,
#  'بنایا': 789,
#  'ہندوستانی': 5180,
#  'حد': 1478,
#  'تبصرہ': 1109,
#  'خاموش': 1573,
#  'بندوقوں': 802,
#  'توپوں': 1201,
#  'لونڈے': 2950,
#  'کمائی': 4672,
#  'پیدا': 4170,
#  'مثال': 3132,
#  'اچھے': 489,
#  'قائم': 2804,
#  'ہیجڑا': 5234,
#  'ٹھگوں': 3888,
#  'جوڑی': 1403,
#  'ہجڑہ': 5142,
#  'اقوام': 301,
#  'متحدہ': 3129,
#  'مستقل': 3254,
#  'مندوب': 3390,
#  'سید': 2340,
#  'اکبرالدین': 498,
#  'جھوٹوں': 1419,
#  'سردار': 2150,
#  'نکلا': 3651,
#  'پٹواریوں': 4077,
#  'لفافہ': 2919,
#  'صح': 2500,
#  'کشیدگی': 4652,
#  'درد': 1706,
#  'فلسطینی': 2761,
#  'ریلی': 2021,
#  'چونچ': 4326,
#  'رکھو': 1988,
#  'ہندووں': 5181,
#  'ٹیپو': 3897,
#  'سلطان': 2200,
#  'چکے': 4353,
#  'ماوں': 3114,
#  'گر': 4929,
#  'جایا': 1311,
#  'حضور': 1510,
#  'فرمایا': 2736,
#  'جنگوں': 1383,
#  'آغاز': 73,
#  'تعالی': 1151,
#  'عجمیوں': 2588,
#  'لشکر': 2910,
#  'اٹھائے': 464,
#  'بہترہن': 1001,
#  'سوار': 2254,
#  'گند': 4992,
#  'اٹھاؤ': 463,
#  'بھڑوے': 971,
#  'دماغ': 1764,
#  'پیدل': 4173,
#  'ارسطو': 212,
#  'عمران': 2630,
#  'سرکار': 2159,
#  'سالمعیشت': 2112,
#  'قرضوں': 2835,
#  'انبار': 357,
#  'دوستوں': 1787,
#  'موڑ': 3436,
#  'قادیانی': 2810,
#  'کافر': 4510,
#  'مرتد': 3200,
#  'بتائے': 638,
#  'قمر': 2851,
#  'بکنے': 900,
#  'سینیٹرز': 2364,
#  'بنانے': 786,
#  'اعلان': 274,
#  'اسکا': 249,
#  'ظالم': 2563,
#  'ہمیشہ': 5174,
#  'صفحہ': 2516,
#  'ہستی': 5152,
#  'مٹے': 3444,
#  'تاریخ': 1089,
#  'تھو': 1222,
#  'کررہی': 4591,
#  'ضمن': 2535,
#  'بلند': 755,
#  'اربوں': 209,
#  'کھا': 4776,
#  'ترس': 1131,
#  'ارہا': 217,
#  'یورپ': 5298,
#  'پھانسی': 4117,
#  'جج': 1325,
#  'بلیک': 767,
#  'لڑکیوں': 2994,
#  'رو': 1951,
#  'پوچھتے': 4061,
#  'گندا': 4993,
#  'لفظ': 2922,
#  'استعمال': 225,
#  'شمار': 2436,
#  'چننے': 4289,
#  'برے': 719,
#  'جرنیل': 1335,
#  'جاہل': 1308,
#  'کم': 4671,
#  'ظرف': 2567,
#  'صورتحال': 2526,
#  'سنگینی': 2245,
#  'نزاکت': 3563,
#  'اندازہ': 374,
#  'ساڈھے': 2125,
#  'تے': 1252,
#  'اٹھ': 462,
#  'مولوی': 3424,
#  'وی': 3807,
#  'گمراہ': 4982,
#  'ھو': 5081,
#  'سےکشمیر': 2386,
#  'سودا': 2258,
#  'امریکہ': 344,
#  'پیسوں': 4180,
#  'حج': 1473,
#  'گٸ': 5024,
#  'ایجنٹ': 533,
#  'لسانیت': 2908,
#  'رھی': 2000,
#  'ھیں': 5110,
#  'سوچا': 2274,
#  'مخالفین': 3170,
#  'حال': 1461,
#  'جوس': 1400,
#  'خالی': 1572,
#  'ﮈبے': 5319,
#  'پٹاخہ': 4070,
#  'بجائیں': 650,
#  'قینچی': 2867,
#  'قطرے': 2847,
#  'مزید': 3243,
#  'حاصل': 1457,
#  'نطفے': 3584,
#  'چوری': 4319,
#  'نوابشاہ': 3623,
#  'ایل': 544,
#  'کرارا': 4566,
#  'سالہ': 2116,
#  'گینڈے': 5061,
#  'ڈالو': 4411,
#  'پاکستانيوں': 3944,
#  'کالا': 4514,
#  'کردیا': 4583,
#  'ننگی': 3616,
#  'تصاویر': 1143,
#  'دلا': 1744,
#  'کہوں': 4832,
#  'چوکی': 4335,
#  'شاہین': 2407,
#  'بیغرت': 1025,
#  'برگیڈ': 712,
#  'نوکری': 3637,
#  'عید': 2649,
#  'چھٹی': 4373,
#  'بک': 892,
#  'سودے': 2262,
#  'غزنی': 2668,
#  'وردک': 3758,
#  'فضائی': 2751,
#  'حملوں': 1526,
#  'تصادم': 1142,
#  'دوران': 1779,
#  'طالبان': 2545,
#  'عسکریت': 2603,
#  'پسندوں': 4005,
#  'بھاری': 915,
#  'اٹھانا': 467,
#  'حیاء': 1552,
#  'کہیں': 4835,
#  'جگہ': 1412,
#  'غلامی': 2674,
#  'ثبوت': 1257,
#  'کھسرے': 4788,
#  'واپس': 3746,
#  'مرد': 3205,
#  'نئ': 3502,
#  'سالے': 2118,
#  'ہجڑے': 5143,
#  'نسلی': 3568,
#  'کھسری': 4787,
#  'مکمل': 3458,
#  'پار': 3916,
#  'کرلی': 4601,
#  'یے': 5317,
#  'وجا': 3749,
#  'کاسودا': 4506,
#  'انریکا': 384,
#  ...}

# %% [markdown]
# ## Test Train Split
# 1. 75% Training 25% Testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test1,y_train,y_test1 = train_test_split(X_train, y_train, test_size=0.20, random_state=0)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %% [markdown]
# # Decision Tree Evaluation
# 1. Test Train split Accuracy, precision, recall and f1 score
# 2. F1 Score for 10 Fold Cross Validation

# %%
from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,pred)
print("----------------Test Train Score Complete Datasets---------------")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# ----------------Test Train Score Complete Datasets---------------
# confusion matrix
# [[1027   35]
#  [ 520  588]]
# Accuracy score: 0.7442396313364056
# Precision score: 0.8038428854687942
# F1 score: 0.7333254505634077
# Recall score: 0.7488646175392795

# %% [markdown]
# ## AUC ROC Curve
# 1. AUC Value
# 2. Curve

# %%
# submission={
#     'id':data['id'],
#     'target':test_pred,
#     'score':dtc_probs,
# }

# submission=pd.DataFrame(submission)
# submission.to_csv("subt.csv")
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
lr_auc = roc_auc_score(y_test, dtc_probs)
# summarize scores
print('Classifier: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(y_test, dtc_probs)
# plot the roc curve for the model
pyplot.plot(lr_fpr, lr_tpr, 'r',marker='.', label='Decision Tree')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
kf = KFold(n_splits=4)
mae_train = []
mae_test = []
# Out:
# Classifier: ROC AUC=0.765

# %% [markdown]
# ## Learning Curve

# %%
# imports
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np
def plot_curve():
    # instantiate
    lg = DecisionTreeClassifier()

    # fit
    lg.fit(X_test, y_test)
    
    
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    train_sizes, train_scores, test_scores = learning_curve(lg, X_test, y_test, n_jobs=-1, cv=10, train_sizes=np.linspace(.1, 1.0, 5), verbose=0)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.figure()
    plt.title("Decison Tree")
    plt.legend(loc="best")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.gca().invert_yaxis()
    
    # box-like grid
    plt.grid()
    
    # plot the std deviation as a transparent range at each training set size
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    # plot the average training and test score lines at each training set size
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    # sizes the window for readability and displays the plot
    # shows error from 0 to 1.1
    plt.ylim(-.1,1.1)
    plt.show()
plot_curve()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %% [markdown]
# ## Logistic Regression
# 1. Test Train split Accuracy, precision, recall and f1 score
# 2. F1 Score for 10 Fold Cross Validation

# %%
cm=confusion_matrix(y_test,pred)
print("Complete Dataset Results")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# Complete Dataset Results
# confusion matrix
# [[997  65]
#  [417 691]]
# Accuracy score: 0.7778801843317973
# Precision score: 0.8095565508931846
# F1 score: 0.7733737441671809
# Recall score: 0.7812204681583008

# %% [markdown]
# #AUC ROC Curve

# %%
# submission={
#     'id':data['id'],
#     'target':test_pred,
#     'score':dtc_probs,
# }

# submission=pd.DataFrame(submission)
# submission.to_csv("subt.csv")
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
lr_auc = roc_auc_score(y_test, dtc_probs)
# summarize scores
print('Classifier: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(y_test, dtc_probs)
# plot the roc curve for the model
pyplot.plot(lr_fpr, lr_tpr, 'r',marker='.', label='Logistic Regression')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
kf = KFold(n_splits=4)
mae_train = []
mae_test = []
# Out:
# Classifier: ROC AUC=0.825

# %% [markdown]
# ## Learning Curve

# %%
# imports
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np
def plot_curve():
    # instantiate
    lg = LogisticRegression()

    # fit
    lg.fit(X_test , y_test)
    
    
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    train_sizes, train_scores, test_scores = learning_curve(lg, X_test, y_test, n_jobs=-1, cv=10, train_sizes=np.linspace(.1, 1.0, 5), verbose=0)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.figure()
    plt.title("Logistic Regression")
    plt.legend(loc="best")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.gca().invert_yaxis()
    
    # box-like grid
    plt.grid()
    
    # plot the std deviation as a transparent range at each training set size
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    # plot the average training and test score lines at each training set size
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    # sizes the window for readability and displays the plot
    # shows error from 0 to 1.1
    plt.ylim(-.1,1.1)
    plt.show()
plot_curve()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
classifier=SVC(probability=True)
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %% [markdown]
# ## SVM
# 1. Test Train split Accuracy, precision, recall and f1 score
# 2. F1 Score for 10 Fold Cross Validation

# %%
cm=confusion_matrix(y_test,pred)
print("Complete Dataset Score")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
# Out:
# Complete Dataset Score
# confusion matrix
# [[1037   25]
#  [ 545  563]]
# Accuracy score: 0.7373271889400922
# Precision score: 0.8064911805430137
# F1 score: 0.724166321753775

# %% [markdown]
# ## AUC ROC Curve

# %%
# submission={
#     'id':data['id'],
#     'target':test_pred,
#     'score':dtc_probs,
# }

# submission=pd.DataFrame(submission)
# submission.to_csv("subt.csv")
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
lr_auc = roc_auc_score(y_test, dtc_probs)
# summarize scores
print('Classifier: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(y_test, dtc_probs)
# plot the roc curve for the model
pyplot.plot(lr_fpr, lr_tpr, 'r',marker='.', label='SVM')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
kf = KFold(n_splits=4)
mae_train = []
mae_test = []
# Out:
# Classifier: ROC AUC=0.825

# %% [markdown]
# ## Learning Curve

# %%
# imports
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np
def plot_curve():
    # instantiate
    lg = SVC()

    # fit
    lg.fit(X_test, y_test)
    
    
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    train_sizes, train_scores, test_scores = learning_curve(lg, X_test, y_test, n_jobs=-1, cv=10, train_sizes=np.linspace(.1, 1.0, 5), verbose=0)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.figure()
    plt.title("SVM")
    plt.legend(loc="best")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.gca().invert_yaxis()
    
    # box-like grid
    plt.grid()
    
    # plot the std deviation as a transparent range at each training set size
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    # plot the average training and test score lines at each training set size
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    # sizes the window for readability and displays the plot
    # shows error from 0 to 1.1
    plt.ylim(-.1,1.1)
    plt.show()
plot_curve()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %% [markdown]
# ## Naive Bayes
# 1. Test Train split Accuracy, precision, recall and f1 score
# 2. F1 Score for 10 Fold Cross Validation

# %%
cm=confusion_matrix(y_test,pred)
print("Complete Dataset Results")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# Complete Dataset Results
# confusion matrix
# [[415 647]
#  [176 932]]
# Accuracy score: 0.6207373271889401
# Precision score: 0.6462233266787327
# F1 score: 0.5979139100655145
# Recall score: 0.6159636813586516

# %% [markdown]
# ## AUC ROC Curve

# %%
# submission={
#     'id':data['id'],
#     'target':test_pred,
#     'score':dtc_probs,
# }

# submission=pd.DataFrame(submission)
# submission.to_csv("subt.csv")
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
lr_auc = roc_auc_score(y_test, dtc_probs)
# summarize scores
print('Classifier: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(y_test, dtc_probs)
# plot the roc curve for the model
pyplot.plot(lr_fpr, lr_tpr, 'r',marker='.', label='Naive Bayes')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
kf = KFold(n_splits=4)
mae_train = []
mae_test = []
# Out:
# Classifier: ROC AUC=0.616

# %% [markdown]
# ## Learning Curve

# %%
# imports
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np
def plot_curve():
    # instantiate
    lg = GaussianNB()

    # fit
    lg.fit(X_test, y_test)
    
    
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    train_sizes, train_scores, test_scores = learning_curve(lg, X_test, y_test, n_jobs=-1, cv=10, train_sizes=np.linspace(.1, 1.0, 5), verbose=0)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.figure()
    plt.title("Naive Bayes")
    plt.legend(loc="best")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.gca().invert_yaxis()
    
    # box-like grid
    plt.grid()
    
    # plot the std deviation as a transparent range at each training set size
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    # plot the average training and test score lines at each training set size
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    # sizes the window for readability and displays the plot
    # shows error from 0 to 1.1
    plt.ylim(-.1,1.1)
    plt.show()
plot_curve()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %% [markdown]
# ## Random Forest
# 1. Test Train split Accuracy, precision, recall and f1 score
# 2. F1 Score for 10 Fold Cross Validation

# %%
cm=confusion_matrix(y_test,pred)
print("confusion matrix")
print("Complete Dataset Results")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# confusion matrix
# Complete Dataset Results
# [[1032   30]
#  [ 492  616]]
# Accuracy score: 0.759447004608295
# Precision score: 0.8153628629238683
# F1 score: 0.7502691891520079
# Recall score: 0.7638540455648698

# %% [markdown]
# ## AUC ROC Curve

# %%
# submission={
#     'id':data['id'],
#     'target':test_pred,
#     'score':dtc_probs,
# }

# submission=pd.DataFrame(submission)
# submission.to_csv("subt.csv")
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
lr_auc = roc_auc_score(y_test, dtc_probs)
# summarize scores
print('Classifier: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(y_test, dtc_probs)
# plot the roc curve for the model
pyplot.plot(lr_fpr, lr_tpr, 'r',marker='.', label='Random Forest')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
kf = KFold(n_splits=4)
mae_train = []
mae_test = []
# Out:
# Classifier: ROC AUC=0.859

# %% [markdown]
# ## Learning Curve

# %%
# imports
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np
def plot_curve():
    # instantiate
    lg = RandomForestClassifier()

    # fit
    lg.fit(X_test, y_test)
    
    
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    train_sizes, train_scores, test_scores = learning_curve(lg, X_test, y_test, n_jobs=-1, cv=10, train_sizes=np.linspace(.1, 1.0, 5), verbose=0)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.figure()
    plt.title("Random Forest")
    plt.legend(loc="best")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.gca().invert_yaxis()
    
    # box-like grid
    plt.grid()
    
    # plot the std deviation as a transparent range at each training set size
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    # plot the average training and test score lines at each training set size
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    # sizes the window for readability and displays the plot
    # shows error from 0 to 1.1
    plt.ylim(-.1,1.1)
    plt.show()
plot_curve()
# Out:
# No handles with labels found to put in legend.
