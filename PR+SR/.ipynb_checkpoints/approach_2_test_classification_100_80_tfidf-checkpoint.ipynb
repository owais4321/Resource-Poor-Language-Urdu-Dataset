# %% [markdown]
# **Importing pandas here**

# %%
import pandas as pd

# %% [markdown]
# **Importing dataset and Having a look at dataset**

# %%
train=pd.read_csv("Dataset 1.csv")
test=pd.read_csv("Dataset 2.csv")
stopw=pd.read_csv("Stopword.csv")
test=test[['tweet','target']]
test.head()
# Out:
#                                                tweet  target
# 0                             کہ کے لے لی شام دلے کی       1
# 1  اب اگر اس نے کچھ جواب دیا تو اس کی گانڈ مار دی...       1
# 2  اب ان چوتیوں نے وہ جو کنسرٹ ہو رہا تھا وہ بھی ...       1
# 3  اب ان کی گانڈ میں ہاتھ ڈال کر انتڑیاں نکالے گا...       1
# 4                      اب تک سکی سب سے اچھی ویڈیو ہے       0

# %% [markdown]
# ### Dataset Cleaning process
# 1. Remove Missing values

# %%
nan_value = float("NaN")
train.replace("", nan_value, inplace=True)
train.dropna(subset = ["tweet"], inplace=True)
train.tail()
print(train['target'].value_counts())
nan_value = float("NaN")
test.replace("", nan_value, inplace=True)
test.dropna(subset = ["tweet"], inplace=True)
test.tail()
print(test['target'].value_counts())
# Out:
# 0    1213
# 1    1187
# Name: target, dtype: int64
# 1    1108
# 0    1062
# Name: target, dtype: int64

# %% [markdown]
# ### Dataset Cleaning process
# 2. Acquring Stopwords

# %%
stopwords=[]
for i in (stopw['Stopwords']):
    stopwords.append(i)

# %% [markdown]
# ### Dataset Cleaning process
# 1. Remove Missing values
# 2. Tokenization
# 3. Cleaning Extra Characters
# 4. Removal of Stopwords

# %%
from urduhack.preprocessing import remove_punctuation
tain_corpus=[]
for i in (train['tweet']):
        i=remove_punctuation(i)
        review=i.split()
        review=[word for word in review if word not in stopwords]
        review=' '.join(review)
        tain_corpus.append(review)
test_corpus=[]
for i in (test['tweet']):
        i=remove_punctuation(i)
        review=i.split()
        review=[word for word in review if word not in stopwords]
        review=' '.join(review)
        test_corpus.append(review)

# %% [markdown]
# ### Feature Extraction
# 1. **TFIDF** Term Frequency Inverse Document Frequencey
# 2. Looking at vocubalary

# %%
# from sklearn.feature_extraction.text import CountVectorizer    
# cv=CountVectorizer(max_features=3000)
from sklearn.feature_extraction.text import TfidfVectorizer
max_feature_num = 10000
train_vectorizer = TfidfVectorizer(max_features=max_feature_num)
X_train=train_vectorizer.fit_transform(tain_corpus).toarray()
y_train=train['target']
train_vectorizer.vocabulary_
test_vectorizer = TfidfVectorizer(max_features=max_feature_num,vocabulary=train_vectorizer.vocabulary_)
X_test=test_vectorizer.fit_transform(test_corpus).toarray()
y_test=test['target']
train_vectorizer.vocabulary_
# Out:
# {'قوم': 2869,
#  'پرانے': 4001,
#  'خاندانی': 1585,
#  'نمک': 3628,
#  'حرام': 1487,
#  'خنزیروں': 1634,
#  'بغض': 738,
#  'نواز': 3644,
#  'سپورٹ': 2305,
#  'پاکستان': 3973,
#  'قبضے': 2834,
#  'اسرائیلی': 232,
#  'پائلٹ': 3938,
#  'شریف': 2442,
#  'نواسہ': 3647,
#  'مستقبل': 3271,
#  'وزیر': 3792,
#  'اعظم': 273,
#  'ٹویٹر': 3891,
#  'پہ': 4167,
#  'بکواس': 902,
#  'آسان': 68,
#  'کشمیوں': 4678,
#  'مشکل': 3288,
#  'وقت': 3813,
#  'تنہا': 1192,
#  'چھوڑے': 4398,
#  'جبکہ': 1323,
#  'سندھیوں': 2247,
#  'بلوچوں': 762,
#  'پشتونوں': 4041,
#  'زندہ': 2078,
#  'مادرچود': 3091,
#  'یوتھئے': 5324,
#  'کشمیر': 4673,
#  'ہاتھہ': 5156,
#  'نکل': 3670,
#  'ثالثی': 1260,
#  'نیازی': 3698,
#  'واہ': 3769,
#  'کررہے': 4620,
#  'بھوسڑی': 945,
#  'گانڈو': 4941,
#  'بیچنے': 1067,
#  'کتو': 4581,
#  'عالمی': 2591,
#  'سازش': 2119,
#  'ہمارےسلیکٹڈ': 5197,
#  'سلیکٹرز': 2215,
#  'کےمنہ': 4920,
#  'سعودی': 2192,
#  'عرب': 2608,
#  'شرمناک': 2432,
#  'طمانچہ': 2569,
#  'کتی': 4586,
#  'بچے': 879,
#  'گھٹیا': 5075,
#  'پیداوار': 4199,
#  'بہتر': 1002,
#  'انکو': 422,
#  'گھر': 5059,
#  'بھیج': 983,
#  'کنجروں': 4727,
#  'موجیں': 3432,
#  'نیب': 3699,
#  'ڈرامہ': 4457,
#  'آج': 42,
#  'دل': 1750,
#  'خدا': 1599,
#  'قسم': 2852,
#  'خون': 1661,
#  'آنسو': 99,
#  'رویا': 1986,
#  'قبرستان': 2831,
#  'قبروں': 2832,
#  'حالت': 1468,
#  'دیکھی': 1866,
#  'لعنت': 2926,
#  'ٹوٹ': 3884,
#  'شرمی': 2435,
#  'انتہا': 368,
#  'اندر': 379,
#  'رنڈی': 1951,
#  'وآپس': 3736,
#  'عوام': 2653,
#  'جہاں': 1438,
#  'نظر': 3604,
#  'پکڑ': 4136,
#  'گانڈ': 4940,
#  'کیڑا': 4896,
#  'مارے': 3110,
#  'جاو': 1296,
#  'جاکر': 1302,
#  'کشمیریوں': 4677,
#  'ساتھ': 2105,
#  'مل': 3352,
#  'جنگ': 1384,
#  'جنرل': 1378,
#  'باجوہ': 589,
#  'نام': 3541,
#  'سن': 2236,
#  'مودی': 3433,
#  'ٹانگیں': 3859,
#  'کانپتی': 4561,
#  'آرمی': 58,
#  'چیف': 4419,
#  'لوامہ': 2955,
#  'بھارتی': 914,
#  'فوج': 2784,
#  'ڈنڈا': 4472,
#  'کیسی': 4878,
#  'خبیث': 1597,
#  'انسان': 389,
#  'جسکے': 1348,
#  'مرنے': 3237,
#  'ہمیں': 5206,
#  'خوشی': 1656,
#  'لعنتی': 2927,
#  'پتا': 3983,
#  'کب': 4569,
#  'مرے': 3249,
#  'کتے': 4588,
#  'موت': 3426,
#  'شروع': 2437,
#  'برا': 694,
#  'لگتا': 3042,
#  'زندگی': 2077,
#  'پہلا': 4173,
#  'ووٹ': 3821,
#  'بار': 595,
#  'سلیکشن': 2214,
#  'گورایہ': 5034,
#  'گٹر': 5053,
#  'فوجیستان': 2786,
#  'بس': 727,
#  'کام': 4549,
#  'ھےالطاف': 5144,
#  'بھائی': 910,
#  'کےاوپر': 4904,
#  'پابندی': 3945,
#  'تالا': 1095,
#  'ڈال': 4433,
#  'مریم': 3247,
#  'احتساب': 175,
#  'عدالت': 2604,
#  'بلا': 744,
#  'سیکنڈز': 2384,
#  'دن': 1774,
#  'ریمانڈ': 2035,
#  'دلوانا': 1760,
#  'تیز': 1250,
#  'ترین': 1139,
#  'کاروائی': 4518,
#  'پارلمنٹ': 3949,
#  'بلڈنگ': 763,
#  'بھیک': 995,
#  'بنا': 772,
#  'بند': 797,
#  'گھسرا': 5064,
#  'گھسرے': 5065,
#  'مزہ': 3261,
#  'آۓ': 133,
#  'بھول': 947,
#  'لوگوں': 2981,
#  'زبان': 2054,
#  'بشری': 733,
#  'پیرنی': 4202,
#  'کہاں': 4851,
#  'بنی': 818,
#  'گالہ': 4935,
#  'کتوں': 4585,
#  'لاکھوں': 2911,
#  'مظلوم': 3306,
#  'ممتاز': 3382,
#  'ماں': 3137,
#  'پھودی': 4153,
#  'حرامی': 1498,
#  'بلوایا': 758,
#  'میکاسنگھ': 3512,
#  'انڈیا': 412,
#  'کرنٹ': 4636,
#  'اکاؤنٹ': 495,
#  'خسارہ': 1615,
#  'کمی': 4713,
#  'کامیابی': 4556,
#  'وزیراعظم': 3793,
#  'خاتمہ': 1568,
#  'انشاءلله': 398,
#  'خود': 1646,
#  'سندھی': 2246,
#  'بولتا': 840,
#  'ھے': 5142,
#  'فخر': 2724,
#  'بلوچ': 759,
#  'ھونے': 5122,
#  'بلوچست': 760,
#  'کاش': 4535,
#  'اج': 163,
#  'موچھیں': 3452,
#  'کاٹ': 4562,
#  'پچھواڑا': 4114,
#  'پھاڑ': 4146,
#  'بھیجیں': 990,
#  'طوفانی': 2575,
#  'بارش': 596,
#  'تباہی': 1108,
#  'مچا': 3463,
#  'سینکڑوں': 2372,
#  'مکانات': 3473,
#  'نقصان': 3617,
#  'سیلابی': 2367,
#  'ریلے': 2034,
#  'محصور': 3180,
#  'محترم': 3175,
#  'جناب': 1371,
#  'انکل': 421,
#  'باجرہ': 586,
#  'ایکسٹینشن': 568,
#  'ٹیوٹ': 3927,
#  'قیامت': 2875,
#  'آگئی': 126,
#  'تھیآپ': 1235,
#  'نظریات': 3605,
#  'پہرہ': 4171,
#  'کمینی': 4718,
#  'منہ': 3422,
#  'رکھ': 1995,
#  'سچ': 2307,
#  'حق': 1518,
#  'بولنے': 845,
#  'لکھنے': 3019,
#  'نڈر': 3662,
#  'بیوروچیف': 1044,
#  'ٹرائیبل': 3867,
#  'ٹائمز': 3856,
#  'ڈسٹرک': 4471,
#  'ویسٹ': 3840,
#  'بلدیہ': 755,
#  'ٹاون': 3861,
#  'کراچی': 4598,
#  'میںشہید': 3517,
#  'اوقات': 447,
#  'مادر': 3089,
#  'چود': 4328,
#  'like': 13,
#  'خنزیر': 1632,
#  'اولاد': 450,
#  'جتنا': 1325,
#  'ملک': 3373,
#  'جان': 1281,
#  'بات': 582,
#  'مزاق': 3256,
#  'بھگوڑی': 980,
#  'لیگ': 3075,
#  'پورے': 4077,
#  'کشمیروں': 4674,
#  'علاوہ': 2632,
#  'چھوڑ': 4394,
#  'غلط': 2688,
#  'برگہ': 712,
#  'کشتہ': 4671,
#  'روز': 1966,
#  'اول': 448,
#  'طبیعت': 2564,
#  'صاف': 2509,
#  'چاہئیے': 4272,
#  'لعنتییوں': 2930,
#  'سیاست': 2342,
#  'لیکر': 3074,
#  'اسٹیبلشمنٹ': 244,
#  'کیسیس': 4879,
#  'کالے': 4548,
#  'کرتوتوں': 4603,
#  'بچاتے': 865,
#  'بہن': 1005,
#  'قومی': 2871,
#  'اثاثے': 161,
#  'برباد': 701,
#  'رھا': 2006,
#  'موقع': 3437,
#  'چمکانے': 4306,
#  'نسل': 3582,
#  'شرم': 2430,
#  'ابے': 147,
#  'مار': 3093,
#  'چودوں': 4334,
#  'یار': 5304,
#  'افغانیوں': 293,
#  'چدائی': 4286,
#  'سفید': 2199,
#  'پتہ': 3990,
#  'ڈرا': 4455,
#  'غلیظ': 2690,
#  'بیان': 1012,
#  'حکومت': 1554,
#  'پکڑتے': 4138,
#  'پاک': 3971,
#  'لائن': 2887,
#  'آف': 74,
#  'کنٹرول': 4734,
#  'اشتعال': 257,
#  'انگیزی': 430,
#  'توڑ': 1208,
#  'جواب': 1394,
#  'کارروائی': 4513,
#  'افسر': 283,
#  'سمیت': 2232,
#  'فوجی': 2785,
#  'ہلاک': 5189,
#  'ایس': 540,
#  'پی': 4186,
#  'آر': 55,
#  'سوگوار': 2289,
#  'اتنے': 158,
#  'کنجری': 4728,
#  'گشتی': 4996,
#  'دلے': 1768,
#  'جھولی': 1420,
#  'بیٹھ': 1052,
#  'زراہ': 2065,
#  'غور': 2694,
#  'تیرا': 1248,
#  'بھونکنا': 954,
#  'ہوگا': 5246,
#  'ہتھے': 5170,
#  'مر': 3211,
#  'جاۓ': 1320,
#  'عبدالقدیر': 2596,
#  'خان': 1582,
#  'کارگل': 4528,
#  'دہلی': 1844,
#  'منٹ': 3415,
#  'بٹن': 856,
#  'کلک': 4694,
#  'تباہ': 1104,
#  'کرسکتے': 4623,
#  'تھےیہ': 1239,
#  'لکھتے': 3017,
#  'ریے': 2044,
#  'حلال': 1526,
#  'زادے': 2050,
#  'شک': 2464,
#  'کارتک': 4512,
#  'اچھی': 489,
#  'خاصی': 1576,
#  'چکی': 4377,
#  'کمنٹس': 4709,
#  'لہذا': 3055,
#  'کہوںگا': 4860,
#  'بریکنگ': 719,
#  'نیوز': 3706,
#  'اچانک': 483,
#  'شاندار': 2416,
#  'زرداری': 2066,
#  'اینڈ': 552,
#  'کمپنی': 4711,
#  'کمر': 4705,
#  'خبر': 1594,
#  'پاگل': 3980,
#  'زرا': 2062,
#  'سنبھال': 2240,
#  'بدکردار': 689,
#  'باپ': 627,
#  'واشل': 3749,
#  'گدھا': 4953,
#  'راگنی': 1921,
#  'خوروں': 1650,
#  'گدھی': 4954,
#  'بچو': 872,
#  'لگ': 3025,
#  'باری': 600,
#  'لال': 2897,
#  'مرچیں': 3242,
#  'لڑتی': 2998,
#  'گائے': 4931,
#  'پیشاپ': 4212,
#  'پینے': 4223,
#  'گندی': 5024,
#  'کشمیری': 4676,
#  'اللہ': 324,
#  'لاکھ': 2910,
#  'شکر': 2469,
#  'اداکرتے': 199,
#  'ضمیر': 2550,
#  'فروشوں': 2755,
#  'پاکستانیوں': 3977,
#  'چھوٹی': 4391,
#  'علماء': 2635,
#  'کرام': 4596,
#  'آقا': 84,
#  'علیہ': 2641,
#  'السلام': 315,
#  'وارث': 3745,
#  'حثیت': 1478,
#  'بارے': 601,
#  'ٹیکسی': 3932,
#  'لاوارث': 2903,
#  'دنیا': 1776,
#  'بہترین': 1004,
#  'ہتھیار': 5168,
#  'ایمانداری': 548,
#  'تلوار': 1174,
#  'دیانتداری': 1846,
#  'بچی': 876,
#  'خور': 1649,
#  'جھنڈے': 1419,
#  'ناپاک': 3550,
#  'مت': 3146,
#  'شیر': 2496,
#  'کہتے': 4853,
#  'کتا': 4571,
#  'حضرات': 1514,
#  'مسلم': 3279,
#  'حانے': 1474,
#  'خواب': 1639,
#  'دیکھتے': 1861,
#  'جاگ': 1303,
#  'پوری': 4076,
#  'میٹرو': 3506,
#  'پشاور': 4038,
#  'لیگی': 3076,
#  'میڈیا': 3510,
#  'ٹیم': 3923,
#  'پھڈے': 4157,
#  'جاری': 1277,
#  'کنجر': 4723,
#  'بیغیرت': 1030,
#  'بیغیرتوں': 1032,
#  'دردی': 1714,
#  'وٹا': 3823,
#  'پن': 4057,
#  'گاڑی': 4945,
#  'لیٹا': 3070,
#  'سوات': 2263,
#  'دوسرے': 1799,
#  'وزیرستانی': 3795,
#  'بن': 771,
#  'دلال': 1752,
#  'بنےگا': 823,
#  'یارب': 5305,
#  'العزت': 317,
#  'شہ': 2478,
#  'رگ': 2005,
#  'جلدازجلد': 1359,
#  'بھارت': 912,
#  'قابض': 2818,
#  'افواج': 295,
#  'آزادی': 66,
#  'نصیب': 3599,
#  'فرماء': 2742,
#  'آمی': 94,
#  'بوری': 836,
#  'ادارے': 195,
#  'وجہ': 3772,
#  'بھونک': 951,
#  'بےغیرت': 1081,
#  'حاجی': 1458,
#  'جامل': 1280,
#  'حالتی': 1469,
#  'انتقال': 366,
#  'کرگئے': 4658,
#  'نماز': 3624,
#  'جنازہ': 1373,
#  'گیارہ': 5082,
#  'بجے': 661,
#  'نڑیل': 3663,
#  'پیر': 4201,
#  'ادا': 192,
#  'جائےگی': 1270,
#  'ٹھوکو': 3913,
#  'ویسے': 3842,
#  'مرواتے': 3240,
#  'تع': 1154,
#  'مشہور': 3291,
#  'زمانہ': 2071,
#  'بےغیرتوں': 1083,
#  'پہچان': 4184,
#  'دوستو': 1791,
#  'قابل': 2819,
#  'اسکے': 254,
#  'سنو': 2250,
#  'حافظ': 1465,
#  'بلاتحقیق': 746,
#  'خارجہ': 1573,
#  'کہنے': 4857,
#  'دشنام': 1734,
#  'طرازی': 2565,
#  'سر': 2154,
#  'جوابي': 1396,
#  'كارواي': 2881,
#  'نهى': 3636,
#  'انكو': 405,
#  'سبق': 2143,
#  'سكها': 2201,
#  'دينا': 1808,
#  'بہنوں': 1007,
#  'بیٹیوں': 1060,
#  'جیل': 1450,
#  'بھیجتی': 986,
#  'سیدھا': 2355,
#  'گولی': 5046,
#  'مارتے': 3098,
#  'کوس': 4751,
#  'ہورہاہے': 5231,
#  'چور': 4339,
#  'چایئے': 4284,
#  'سزا': 2178,
#  'رات': 1899,
#  'کٹ': 4785,
#  'ہات': 5153,
#  'ہولناک': 5236,
#  'خبریں': 1596,
#  'پڑھ': 4128,
#  'گھنٹوں': 5068,
#  'اداس': 196,
#  'حیا': 1557,
#  'معصوم': 3325,
#  'الگ': 336,
#  'گیراج': 5085,
#  'گرفتار': 4969,
#  'کھوتی': 4827,
#  'پرانی': 4000,
#  'عادتیں': 2588,
#  'خاموشی': 1581,
#  'اختیار': 187,
#  'کرلیتا': 4631,
#  'مسلمان': 3280,
#  'ضیاء': 2552,
#  'جشن': 1351,
#  'منارہے': 3392,
#  'نظریاتی': 3606,
#  'سرحدوں': 2158,
#  'اشد': 259,
#  'ضرورت': 2546,
#  'بیشک': 1024,
#  'ھم': 5107,
#  'گناہگار': 5015,
#  'سیاہکار': 2349,
#  'دیکھیں': 1867,
#  'حامد': 1472,
#  'ماضی': 3114,
#  'ایکسٹنشنز': 567,
#  'نری': 3578,
#  'اوئے': 434,
#  'گمشدہ': 5011,
#  'کتورے': 4583,
#  'اوہ': 458,
#  'اک': 494,
#  'پورا': 4074,
#  'میگزین': 3514,
#  'شکل': 2473,
#  'دیکھ': 1856,
#  'آئینے': 32,
#  'سکتے': 2317,
#  'توآپکا': 1196,
#  'اخلاقی': 191,
#  'فرض': 2736,
#  'خلاف': 1628,
#  'الزام': 314,
#  'لگائے': 3029,
#  'ئے': 136,
#  'بیشاب': 1022,
#  'آپکے': 118,
#  'صحیح': 2521,
#  'ھمارے': 5109,
#  'جانبازوں': 1285,
#  'آپکی': 117,
#  'چیخیں': 4415,
#  'گئ': 4929,
#  'قاتل': 2820,
#  'حل': 1525,
#  'اکٹھے': 503,
#  'باندھ': 620,
#  'بیس': 1020,
#  'میل': 3500,
#  'دور': 1784,
#  'سمندر': 2231,
#  'پھینک': 4164,
#  'کتیا': 4587,
#  'ہیرا': 5270,
#  'منڈی': 3417,
#  'گزارتی': 4982,
#  'ضلع': 2548,
#  'باجوڑ': 588,
#  'تعلق': 1159,
#  'نوجوان': 3648,
#  'ناران': 3532,
#  'کاغان': 4537,
#  'سیر': 2359,
#  'کیلئے': 4881,
#  'جارہے': 1276,
#  'راستے': 1909,
#  'کار': 4511,
#  'حادثے': 1461,
#  'شکار': 2466,
#  'حضرت': 1515,
#  'داتا': 1674,
#  'گنج': 5016,
#  'بخش': 668,
#  'رحمتہ': 1929,
#  'فرمان': 2748,
#  'عاجزی': 2585,
#  'تکبر': 1216,
#  'نفس': 3615,
#  'فریب': 2758,
#  'سپریم': 2301,
#  'کورٹ': 4749,
#  'نااہل': 3523,
#  'شخص': 2422,
#  'ڈی': 4489,
#  'فیکٹو': 2814,
#  'فرائض': 2726,
#  'انجام': 372,
#  'سال': 2121,
#  'اٹالین': 463,
#  'گورنمنٹ': 5037,
#  'کوئ': 4739,
#  'غفور': 2683,
#  'دیکھا': 1857,
#  'لکھتا': 3016,
#  'سیالکوٹ': 2346,
#  'جوتوں': 1401,
#  'سیزن': 2362,
#  'چل': 4291,
#  'پڑا': 4118,
#  'سلسلے': 2209,
#  'بسنے': 731,
#  'مائیں': 3085,
#  'بہنیں': 1008,
#  'آتیں': 41,
#  'شہر': 2483,
#  'لوٹ': 2968,
#  'بلاول': 751,
#  'بغیرت': 740,
#  'غیرت': 2697,
#  'مسلمانوں': 3281,
#  'قتل': 2836,
#  'عام': 2592,
#  'دوسری': 1798,
#  'عظیم': 2621,
#  'ہٹلر': 5258,
#  'مسولینی': 3283,
#  'یہودیوں': 5347,
#  'بل': 743,
#  'گھس': 5063,
#  'جانا': 1282,
#  'چاہیے': 4281,
#  'ڈوب': 4475,
#  'مقام': 3343,
#  'پائن': 3939,
#  'تسی': 1141,
#  'دونگا': 1802,
#  'حرامیوں': 1499,
#  'بھڑوا': 967,
#  'ظلم': 2582,
#  'ماتا': 3087,
#  'بیٹی': 1058,
#  'بیچ': 1062,
#  'تربیت': 1131,
#  'چلتا': 4298,
#  'تخم': 1127,
#  'انڈین': 415,
#  'چاہتے': 4276,
#  'عزت': 2611,
#  'سمجهتے': 2221,
#  'هيں': 3734,
#  'دوسروں': 1797,
#  'حالیہ': 1471,
#  'بارشوں': 597,
#  'حالات': 1467,
#  'سارے': 2117,
#  'ڈھٹائی': 4486,
#  'چادر': 4244,
#  'اوڑھ': 457,
#  'غیرتی': 2701,
#  'نیند': 3704,
#  'جھریوں': 1418,
#  'لوڑے': 2976,
#  'لکھنا': 3018,
#  'سیکھ': 2389,
#  'گت': 4952,
#  'سور': 2273,
#  'کمینے': 4719,
#  'ذلیل': 1885,
#  'لاشوں': 2895,
#  'انصاف': 401,
#  'بلوچستان': 761,
#  'کلبھوشن': 4690,
#  'گرفتاری': 4971,
#  'مجرم': 3161,
#  'قرار': 2843,
#  'اسکی': 253,
#  'شیخ': 2492,
#  'رشید': 1941,
#  'ماری': 3107,
#  'ہوگی': 5249,
#  'مہاجروں': 3480,
#  'غیر': 2696,
#  'مہاجر': 3479,
#  'شامل': 2413,
#  'ہوگئے': 5245,
#  'کاٹنے': 4564,
#  'ہمت': 5199,
#  'رنڈیوں': 1955,
#  'خاندان': 1583,
#  'فرد': 2732,
#  'چودی': 4337,
#  'غلطی': 2689,
#  'میر': 3496,
#  'الٹا': 335,
#  'لٹکانا': 2991,
#  'کنجھر': 4729,
#  'خسرے': 1616,
#  'روڈ': 1981,
#  'بیٹا': 1050,
#  'باب': 578,
#  'اتنی': 157,
#  'ہمدردی': 5202,
#  'بندہ': 806,
#  'امی': 352,
#  'قطری': 2859,
#  'خیال': 1664,
#  'کان': 4557,
#  'شا': 2402,
#  'چاند': 4251,
#  'پہنچ': 4177,
#  'لوگ': 2979,
#  'مہنگائی': 3486,
#  'ست': 2148,
#  'درگور': 1724,
#  'بچوں': 873,
#  'دفع': 1743,
#  'ہاہا': 5164,
#  'فکر': 2801,
#  'بولے': 847,
#  'چیز': 4416,
#  'یکجہتی': 5343,
#  'ہوۓ': 5253,
#  'گندگی': 5022,
#  'بدبو': 672,
#  'امید': 353,
#  'سکتی': 2316,
#  'گرین': 4980,
#  'پاسپورٹ': 3955,
#  'عبرت': 2598,
#  'نشان': 3590,
#  'میکسیکو': 3513,
#  'برازیل': 698,
#  'پاکستانی': 3975,
#  'خاتون': 1569,
#  'ھر': 5104,
#  'لاھور': 2912,
#  'مانگتا': 3128,
#  'ھوئی': 5113,
#  'زلیل': 2070,
#  'انیل': 432,
#  'مسرت': 3275,
#  'حرکت': 1500,
#  'جرت': 1335,
#  'پاپوش': 3970,
#  'اینکرز': 554,
#  'مبارکباد': 3142,
#  'مستحق': 3269,
#  'کےپیروڈی': 4924,
#  'ٹائپ': 3858,
#  'تبصروں': 1111,
#  'دکھایا': 1817,
#  'اجتک': 167,
#  'کرسکی': 4624,
#  'چوتیے': 4327,
#  'بیچا': 1063,
#  'گنجے': 5019,
#  'ناندیڑ': 3548,
#  'ٹریکٹرحادثہ': 3872,
#  'کاشکارڈارئیورسید': 4536,
#  'قاسم': 2825,
#  'دوافراد': 1781,
#  'لندن': 2946,
#  'کھسرا': 4812,
#  'چوراہے': 4341,
#  'کھڑا': 4839,
#  'بیڑا': 1068,
#  'غرق': 2676,
#  'سفاکیت': 2197,
#  'ممالک': 3380,
#  'کونسے': 4764,
#  'محترمہ': 3176,
#  'کھوتا': 4825,
#  'کھانے': 4808,
#  'پٹواری': 4103,
#  'سمجھ': 2222,
#  'یقین': 5316,
#  'ابا': 139,
#  'جی': 1441,
#  'فرما': 2741,
#  'پشتون': 4039,
#  'مند': 3406,
#  'انکے': 425,
#  'وفاداری': 3809,
#  'اسکو': 251,
#  'ملانا': 3362,
#  'منا': 3387,
#  'چوکیوں': 4363,
#  'نشانہ': 3591,
#  'بنایا': 790,
#  'ہندوستانی': 5211,
#  'حد': 1484,
#  'تبصرہ': 1112,
#  'خاموش': 1580,
#  'بندوقوں': 803,
#  'توپوں': 1206,
#  'لونڈے': 2966,
#  'کمائی': 4700,
#  'پیدا': 4197,
#  'مثال': 3151,
#  'اچھے': 490,
#  'قائم': 2817,
#  'ہیجڑا': 5266,
#  'ٹھگوں': 3918,
#  'جوڑی': 1407,
#  'ہجڑہ': 5173,
#  'اقوام': 302,
#  'متحدہ': 3148,
#  'مستقل': 3272,
#  'مندوب': 3407,
#  'سید': 2352,
#  'اکبرالدین': 499,
#  'جھوٹوں': 1423,
#  'سردار': 2160,
#  'نکلا': 3671,
#  'پٹواریوں': 4105,
#  'لفافہ': 2933,
#  'صح': 2514,
#  'کشیدگی': 4680,
#  'درد': 1713,
#  'فلسطینی': 2774,
#  'ریلی': 2030,
#  'چونچ': 4351,
#  'رکھو': 1996,
#  'ہندووں': 5212,
#  'ٹیپو': 3928,
#  'سلطان': 2210,
#  'چکے': 4378,
#  'ماوں': 3133,
#  'گر': 4959,
#  'جایا': 1315,
#  'حضور': 1516,
#  'فرمایا': 2749,
#  'جنگوں': 1387,
#  'آغاز': 73,
#  'تعالی': 1155,
#  'عجمیوں': 2602,
#  'لشکر': 2924,
#  'اٹھائے': 467,
#  'بہترہن': 1003,
#  'سوار': 2264,
#  'گند': 5020,
#  'اٹھاؤ': 466,
#  'بھڑوے': 972,
#  'دماغ': 1770,
#  'پیدل': 4200,
#  'ارسطو': 212,
#  'عمران': 2644,
#  'سرکار': 2169,
#  'سالمعیشت': 2123,
#  'قرضوں': 2848,
#  'انبار': 360,
#  'دوستوں': 1793,
#  'موڑ': 3453,
#  'قادیانی': 2823,
#  'کافر': 4538,
#  'مرتد': 3219,
#  'بتائے': 639,
#  'قمر': 2864,
#  'بکنے': 901,
#  'سینیٹرز': 2376,
#  'بنانے': 787,
#  'اعلان': 275,
#  'اسکا': 250,
#  'ظالم': 2577,
#  'ہمیشہ': 5205,
#  'صفحہ': 2530,
#  'ہستی': 5183,
#  'مٹے': 3461,
#  'تاریخ': 1092,
#  'تھو': 1226,
#  'کررہی': 4619,
#  'ضمن': 2549,
#  'بلند': 756,
#  'اربوں': 209,
#  'کھا': 4802,
#  'ترس': 1135,
#  'ارہا': 217,
#  'یورپ': 5330,
#  'پھانسی': 4145,
#  'جج': 1329,
#  'بلیک': 768,
#  'لڑکیوں': 3008,
#  'رو': 1959,
#  'پوچھتے': 4089,
#  'گندا': 5021,
#  'لفظ': 2936,
#  'استعمال': 226,
#  'شمار': 2449,
#  'ننے': 3635,
#  'برے': 720,
#  'جرنیل': 1339,
#  'جاہل': 1312,
#  'کم': 4699,
#  'ظرف': 2581,
#  'صورتحال': 2540,
#  'سنگینی': 2255,
#  'نزاکت': 3581,
#  'اندازہ': 377,
#  'ساڈھے': 2136,
#  'تے': 1256,
#  'ٹھ': 3907,
#  'مولوی': 3441,
#  'وی': 3834,
#  'گمراہ': 5010,
#  'ھو': 5112,
#  'سےکشمیر': 2399,
#  'سودا': 2268,
#  'امریکہ': 347,
#  'پیسوں': 4207,
#  'حج': 1479,
#  'گٸ': 5052,
#  'ایجنٹ': 534,
#  'لسانیت': 2922,
#  'رھی': 2009,
#  'ھیں': 5141,
#  'سوچا': 2284,
#  'مخالفین': 3189,
#  'حال': 1466,
#  'جوس': 1404,
#  'خالی': 1579,
#  'ﮈبے': 5353,
#  'پٹاخہ': 4098,
#  'بجائیں': 651,
#  'قینچی': 2880,
#  'قطرے': 2860,
#  'مزید': 3262,
#  'حاصل': 1462,
#  'نطفے': 3602,
#  'چوری': 4344,
#  'نوابشاہ': 3642,
#  'ایل': 545,
#  'کرارا': 4594,
#  'سالہ': 2127,
#  'گینڈے': 5090,
#  'ڈالو': 4438,
#  'پاکستانيوں': 3974,
#  'کالا': 4542,
#  'کردیا': 4611,
#  'ننگی': 3633,
#  'تصاویر': 1147,
#  'دلا': 1751,
#  'کہوں': 4859,
#  'چوکی': 4360,
#  'شاہین': 2420,
#  'بیغرت': 1027,
#  'برگیڈ': 713,
#  'نوکری': 3656,
#  'عید': 2663,
#  'چھٹی': 4399,
#  'بک': 893,
#  'سودے': 2272,
#  'غزنی': 2681,
#  'وردک': 3782,
#  'فضائی': 2764,
#  'حملوں': 1532,
#  'تصادم': 1146,
#  'دوران': 1785,
#  'طالبان': 2559,
#  'عسکریت': 2617,
#  'پسندوں': 4034,
#  'بھاری': 916,
#  'اٹھانا': 470,
#  'حیاء': 1558,
#  'کہیں': 4862,
#  'جگہ': 1415,
#  'غلامی': 2687,
#  'ثبوت': 1261,
#  'کھسرے': 4814,
#  'واپس': 3767,
#  'مرد': 3224,
#  'نئ': 3519,
#  'سالے': 2129,
#  'ہجڑے': 5174,
#  'نسلی': 3586,
#  'کھسری': 4813,
#  'مکمل': 3475,
#  'پار': 3947,
#  'کرلی': 4629,
#  'یے': 5351,
#  'وجا': 3770,
#  'کاسودا': 4534,
#  'انریکا': 387,
#  'مے': 3518,
#  'خبردار': 1595,
#  ...}

# %% [markdown]
# ## Test Train Split
# 1. 75% Training 25% Testing

# %%
# from sklearn.model_selection import train_test_split
# X_train,X_test1,y_train,y_test1 = train_test_split(X_train, y_train, test_size=0.30, random_state=0)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %% [markdown]
# # Decision Tree Evaluation
# 1. Test Train split Accuracy, precision, recall and f1 score
# 2. F1 Score for 10 Fold Cross Validation

# %%
from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,pred)
print("----------------Test Train Score Complete Datasets---------------")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# ----------------Test Train Score Complete Datasets---------------
# confusion matrix
# [[1016   46]
#  [ 370  738]]
# Accuracy score: 0.808294930875576
# Precision score: 0.8371856318284889
# F1 score: 0.8050961046857079
# Recall score: 0.8113752405039194

# %% [markdown]
# ## AUC ROC Curve
# 1. AUC Value
# 2. Curve

# %%
# submission={
#     'id':data['id'],
#     'target':test_pred,
#     'score':dtc_probs,
# }

# submission=pd.DataFrame(submission)
# submission.to_csv("subt.csv")
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
lr_auc = roc_auc_score(y_test, dtc_probs)
# summarize scores
print('Classifier: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(y_test, dtc_probs)
# plot the roc curve for the model
pyplot.plot(lr_fpr, lr_tpr, 'r',marker='.', label='Decision Tree')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
kf = KFold(n_splits=4)
mae_train = []
mae_test = []
# Out:
# Classifier: ROC AUC=0.818

# %% [markdown]
# ## Learning Curve

# %%
# imports
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np
def plot_curve():
    # instantiate
    lg = DecisionTreeClassifier()

    # fit
    lg.fit(X_test, y_test)
    
    
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    train_sizes, train_scores, test_scores = learning_curve(lg, X_test, y_test, n_jobs=-1, cv=10, train_sizes=np.linspace(.1, 1.0, 5), verbose=0)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.figure()
    plt.title("Decison Tree")
    plt.legend(loc="best")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.gca().invert_yaxis()
    
    # box-like grid
    plt.grid()
    
    # plot the std deviation as a transparent range at each training set size
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    # plot the average training and test score lines at each training set size
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    # sizes the window for readability and displays the plot
    # shows error from 0 to 1.1
    plt.ylim(-.1,1.1)
    plt.show()
plot_curve()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %% [markdown]
# ## Logistic Regression
# 1. Test Train split Accuracy, precision, recall and f1 score
# 2. F1 Score for 10 Fold Cross Validation

# %%
cm=confusion_matrix(y_test,pred)
print("Complete Dataset Results")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# Complete Dataset Results
# confusion matrix
# [[1019   43]
#  [ 494  614]]
# Accuracy score: 0.7525345622119816
# Precision score: 0.8040236770917899
# F1 score: 0.7436035094474546
# Recall score: 0.7568309911820895

# %% [markdown]
# #AUC ROC Curve

# %%
# submission={
#     'id':data['id'],
#     'target':test_pred,
#     'score':dtc_probs,
# }

# submission=pd.DataFrame(submission)
# submission.to_csv("subt.csv")
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
lr_auc = roc_auc_score(y_test, dtc_probs)
# summarize scores
print('Classifier: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(y_test, dtc_probs)
# plot the roc curve for the model
pyplot.plot(lr_fpr, lr_tpr, 'r',marker='.', label='Logistic Regression')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
kf = KFold(n_splits=4)
mae_train = []
mae_test = []
# Out:
# Classifier: ROC AUC=0.826

# %% [markdown]
# ## Learning Curve

# %%
# imports
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np
def plot_curve():
    # instantiate
    lg = LogisticRegression()

    # fit
    lg.fit(X_test , y_test)
    
    
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    train_sizes, train_scores, test_scores = learning_curve(lg, X_test, y_test, n_jobs=-1, cv=10, train_sizes=np.linspace(.1, 1.0, 5), verbose=0)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.figure()
    plt.title("Logistic Regression")
    plt.legend(loc="best")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.gca().invert_yaxis()
    
    # box-like grid
    plt.grid()
    
    # plot the std deviation as a transparent range at each training set size
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    # plot the average training and test score lines at each training set size
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    # sizes the window for readability and displays the plot
    # shows error from 0 to 1.1
    plt.ylim(-.1,1.1)
    plt.show()
plot_curve()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
classifier=SVC(probability=True)
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %% [markdown]
# ## SVM
# 1. Test Train split Accuracy, precision, recall and f1 score
# 2. F1 Score for 10 Fold Cross Validation

# %%
cm=confusion_matrix(y_test,pred)
print("Complete Dataset Score")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
# Out:
# Complete Dataset Score
# confusion matrix
# [[1008   54]
#  [ 508  600]]
# Accuracy score: 0.7410138248847926
# Precision score: 0.7911694221877951
# F1 score: 0.7315229097338961

# %% [markdown]
# ## AUC ROC Curve

# %%
# submission={
#     'id':data['id'],
#     'target':test_pred,
#     'score':dtc_probs,
# }

# submission=pd.DataFrame(submission)
# submission.to_csv("subt.csv")
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
lr_auc = roc_auc_score(y_test, dtc_probs)
# summarize scores
print('Classifier: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(y_test, dtc_probs)
# plot the roc curve for the model
pyplot.plot(lr_fpr, lr_tpr, 'r',marker='.', label='SVM')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
kf = KFold(n_splits=4)
mae_train = []
mae_test = []
# Out:
# Classifier: ROC AUC=0.821

# %% [markdown]
# ## Learning Curve

# %%
# imports
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np
def plot_curve():
    # instantiate
    lg = SVC()

    # fit
    lg.fit(X_test, y_test)
    
    
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    train_sizes, train_scores, test_scores = learning_curve(lg, X_test, y_test, n_jobs=-1, cv=10, train_sizes=np.linspace(.1, 1.0, 5), verbose=0)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.figure()
    plt.title("SVM")
    plt.legend(loc="best")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.gca().invert_yaxis()
    
    # box-like grid
    plt.grid()
    
    # plot the std deviation as a transparent range at each training set size
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    # plot the average training and test score lines at each training set size
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    # sizes the window for readability and displays the plot
    # shows error from 0 to 1.1
    plt.ylim(-.1,1.1)
    plt.show()
plot_curve()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %% [markdown]
# ## Naive Bayes
# 1. Test Train split Accuracy, precision, recall and f1 score
# 2. F1 Score for 10 Fold Cross Validation

# %%
cm=confusion_matrix(y_test,pred)
print("Complete Dataset Results")
print("confusion matrix")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# Complete Dataset Results
# confusion matrix
# [[436 626]
#  [279 829]]
# Accuracy score: 0.5829493087557603
# Precision score: 0.5897748299810155
# F1 score: 0.5688064269436646
# Recall score: 0.5793705426040371

# %% [markdown]
# ## AUC ROC Curve

# %%
# submission={
#     'id':data['id'],
#     'target':test_pred,
#     'score':dtc_probs,
# }

# submission=pd.DataFrame(submission)
# submission.to_csv("subt.csv")
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
lr_auc = roc_auc_score(y_test, dtc_probs)
# summarize scores
print('Classifier: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(y_test, dtc_probs)
# plot the roc curve for the model
pyplot.plot(lr_fpr, lr_tpr, 'r',marker='.', label='Naive Bayes')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
kf = KFold(n_splits=4)
mae_train = []
mae_test = []
# Out:
# Classifier: ROC AUC=0.579

# %% [markdown]
# ## Learning Curve

# %%
# imports
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np
def plot_curve():
    # instantiate
    lg = GaussianNB()

    # fit
    lg.fit(X_test, y_test)
    
    
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    train_sizes, train_scores, test_scores = learning_curve(lg, X_test, y_test, n_jobs=-1, cv=10, train_sizes=np.linspace(.1, 1.0, 5), verbose=0)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.figure()
    plt.title("Naive Bayes")
    plt.legend(loc="best")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.gca().invert_yaxis()
    
    # box-like grid
    plt.grid()
    
    # plot the std deviation as a transparent range at each training set size
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    # plot the average training and test score lines at each training set size
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    # sizes the window for readability and displays the plot
    # shows error from 0 to 1.1
    plt.ylim(-.1,1.1)
    plt.show()
plot_curve()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train,y_train)
pred=classifier.predict(X_test)
dtc_probs = classifier.predict_proba(X_test)
dtc_probs=dtc_probs[:,1]

# %% [markdown]
# ## Random Forest
# 1. Test Train split Accuracy, precision, recall and f1 score
# 2. F1 Score for 10 Fold Cross Validation

# %%
cm=confusion_matrix(y_test,pred)
print("confusion matrix")
print("Complete Dataset Results")
print(cm)
acc=accuracy_score(y_test, pred)
pr=precision_score(y_test, pred,average='macro')
re=recall_score(y_test, pred,average='macro')
fs=f1_score(y_test, pred,average='macro')
print('Accuracy score: {}'.format(acc))
print('Precision score: {}'.format(pr))
print('F1 score: {}'.format(fs))
print('Recall score: {}'.format(re))
# Out:
# confusion matrix
# Complete Dataset Results
# [[1027   35]
#  [ 497  611]]
# Accuracy score: 0.7548387096774194
# Precision score: 0.809852473936114
# F1 score: 0.7454850740016632
# Recall score: 0.7592436789111205

# %% [markdown]
# ## AUC ROC Curve

# %%
# submission={
#     'id':data['id'],
#     'target':test_pred,
#     'score':dtc_probs,
# }

# submission=pd.DataFrame(submission)
# submission.to_csv("subt.csv")
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
lr_auc = roc_auc_score(y_test, dtc_probs)
# summarize scores
print('Classifier: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(y_test, dtc_probs)
# plot the roc curve for the model
pyplot.plot(lr_fpr, lr_tpr, 'r',marker='.', label='Random Forest')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
kf = KFold(n_splits=4)
mae_train = []
mae_test = []
# Out:
# Classifier: ROC AUC=0.834

# %% [markdown]
# ## Learning Curve

# %%
# imports
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np
def plot_curve():
    # instantiate
    lg = RandomForestClassifier()

    # fit
    lg.fit(X_test, y_test)
    
    
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    train_sizes, train_scores, test_scores = learning_curve(lg, X_test, y_test, n_jobs=-1, cv=10, train_sizes=np.linspace(.1, 1.0, 5), verbose=0)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.figure()
    plt.title("Random Forest")
    plt.legend(loc="best")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.gca().invert_yaxis()
    
    # box-like grid
    plt.grid()
    
    # plot the std deviation as a transparent range at each training set size
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    # plot the average training and test score lines at each training set size
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    # sizes the window for readability and displays the plot
    # shows error from 0 to 1.1
    plt.ylim(-.1,1.1)
    plt.show()
plot_curve()
# Out:
# No handles with labels found to put in legend.
